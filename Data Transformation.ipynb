# %% [markdown]
# # Transforming the Data collected in a clean table

# %%
# Dependencies and Setup
import pandas as pd

# Study data files
data_path = "quarterly.csv"

# Read the data 
#Due to errors on row 8 (which had no value assigned), we had to skip this specific row in order to read the file
data_original = pd.read_csv(data_path, encoding='utf-8', skiprows=8)

# Display the data table for preview
data_original.head()
# Out:
#                          Geography                      Canada 1 Canada 1.1  \
# 0                       Statistics  Value per consumption unit 2        NaN
# 1                  Characteristics                All households        NaN
# 2  Income, consumption and savings                       Q1 2020    Q2 2020
# 3                              NaN                       Dollars        NaN
# 4      Household disposable income                        12,182     13,880
#
#   Canada 1.2 Canada 1.3 Canada 1.4 Canada 1.5 Canada 1.6 Canada 1.7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2    Q3 2020    Q4 2020    Q1 2021    Q2 2021    Q3 2021    Q4 2021
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4     14,223     13,847     13,189     13,604     14,707     14,070
#
#   Canada 1.8  ... Nunavut 1.1 Nunavut 1.2 Nunavut 1.3 Nunavut 1.4 Nunavut 1.5  \
# 0        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 1        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 2    Q1 2022  ...     Q2 2020     Q3 2020     Q4 2020     Q1 2021     Q2 2021
# 3        NaN  ...         NaN         NaN         NaN         NaN         NaN
# 4     13,367  ...      19,015      17,948      17,334      16,673      16,826
#
#   Nunavut 1.6 Nunavut 1.7 Nunavut 1.8 Nunavut 1.9 Nunavut 1.10
# 0         NaN         NaN         NaN         NaN          NaN
# 1         NaN         NaN         NaN         NaN          NaN
# 2     Q3 2021     Q4 2021     Q1 2022     Q2 2022      Q3 2022
# 3         NaN         NaN         NaN         NaN          NaN
# 4      17,787      16,755      25,814      26,575       29,117
#
# [5 rows x 155 columns]

# %%
#Drop rows that are not relevant
data_df = data_original.drop([0, 1, 3, 30, 31, 32, 33, 34])

#Reset index
data_df = data_df.reset_index(drop=True)

#Rename main column
data_df = data_df.rename(columns={"Geography":"Categories"})

#Set new index as categories
data_df = data_df.set_index("Categories")

#Rename appropriate rows
data_df = data_df.rename(index={"Income, consumption and savings": "Year Quartile"})

#Display the data table
data_df
# Out:
#                                                    Canada 1 Canada 1.1  \
# Categories
# Year Quartile                                       Q1 2020    Q2 2020
# Household disposable income                          12,182     13,880
# Social transfers in kind (STiK): education            1,134      1,040
# Social transfers in kind (STiK): health               1,736      1,744
# Social transfers in kind (STiK): other                  717        659
# Adjusted household disposable income                 15,769     17,323
# Household final consumption expenditure (HFCE)       11,744     10,961
# Food and non-alcoholic beverages                      1,176      1,251
# Alcoholic beverages and tobacco                         447        496
# Clothing and footwear                                   407        346
# Housing, water, electricity, gas and other fuels      2,991      2,914
# Furnishings, household equipment and other good...      649        776
# Health                                                  519        407
# Transport                                             1,607      1,268
# Communications                                          325        314
# Recreation and culture                                  937        986
# Education                                               176        157
# Food, beverage and accommodation services               811        483
# Insurance and financial services                      1,069      1,053
# Miscellaneous goods and services                        630        508
# Social transfers in kind (STiK)                       3,587      3,443
# Social transfers in kind (STiK): education            1,134      1,040
# Social transfers in kind (STiK): health               1,736      1,744
# Social transfers in kind (STiK): other                  717        659
# Household actual final consumption                   15,331     14,404
# Change in pension entitlements                          315        363
# Household net saving                                    753      3,283
#
#                                                    Canada 1.2 Canada 1.3  \
# Categories
# Year Quartile                                         Q3 2020    Q4 2020
# Household disposable income                            14,223     13,847
# Social transfers in kind (STiK): education              1,100      1,130
# Social transfers in kind (STiK): health                 1,815      1,939
# Social transfers in kind (STiK): other                    682        709
# Adjusted household disposable income                   17,820     17,626
# Household final consumption expenditure (HFCE)         12,616     12,581
# Food and non-alcoholic beverages                        1,264      1,302
# Alcoholic beverages and tobacco                           522        508
# Clothing and footwear                                     554        658
# Housing, water, electricity, gas and other fuels        2,948      2,945
# Furnishings, household equipment and other good...        898        977
# Health                                                    490        502
# Transport                                               1,844      1,630
# Communications                                            326        328
# Recreation and culture                                  1,165      1,147
# Education                                                 146        160
# Food, beverage and accommodation services                 768        629
# Insurance and financial services                        1,064      1,088
# Miscellaneous goods and services                          626        707
# Social transfers in kind (STiK)                         3,597      3,779
# Social transfers in kind (STiK): education              1,100      1,130
# Social transfers in kind (STiK): health                 1,815      1,939
# Social transfers in kind (STiK): other                    682        709
# Household actual final consumption                     16,213     16,360
# Change in pension entitlements                            354        489
# Household net saving                                    1,962      1,755
#
#                                                    Canada 1.4 Canada 1.5  \
# Categories
# Year Quartile                                         Q1 2021    Q2 2021
# Household disposable income                            13,189     13,604
# Social transfers in kind (STiK): education              1,111      1,088
# Social transfers in kind (STiK): health                 2,035      1,991
# Social transfers in kind (STiK): other                    692        672
# Adjusted household disposable income                   17,027     17,356
# Household final consumption expenditure (HFCE)         11,461     12,740
# Food and non-alcoholic beverages                        1,211      1,260
# Alcoholic beverages and tobacco                           442        499
# Clothing and footwear                                     381        473
# Housing, water, electricity, gas and other fuels        2,993      3,044
# Furnishings, household equipment and other good...        758        922
# Health                                                    505        519
# Transport                                               1,482      1,881
# Communications                                            313        314
# Recreation and culture                                    934      1,219
# Education                                                 164        162
# Food, beverage and accommodation services                 594        688
# Insurance and financial services                        1,102      1,142
# Miscellaneous goods and services                          581        618
# Social transfers in kind (STiK)                         3,838      3,752
# Social transfers in kind (STiK): education              1,111      1,088
# Social transfers in kind (STiK): health                 2,035      1,991
# Social transfers in kind (STiK): other                    692        672
# Household actual final consumption                     15,299     16,492
# Change in pension entitlements                            359        489
# Household net saving                                    2,086      1,353
#
#                                                    Canada 1.6 Canada 1.7  \
# Categories
# Year Quartile                                         Q3 2021    Q4 2021
# Household disposable income                            14,707     14,070
# Social transfers in kind (STiK): education              1,094      1,115
# Social transfers in kind (STiK): health                 2,029      2,027
# Social transfers in kind (STiK): other                    694        703
# Adjusted household disposable income                   18,524     17,915
# Household final consumption expenditure (HFCE)         13,544     13,320
# Food and non-alcoholic beverages                        1,263      1,255
# Alcoholic beverages and tobacco                           523        500
# Clothing and footwear                                     631        775
# Housing, water, electricity, gas and other fuels        3,084      3,015
# Furnishings, household equipment and other good...        942        986
# Health                                                    532        520
# Transport                                               2,016      1,813
# Communications                                            329        334
# Recreation and culture                                  1,249      1,201
# Education                                                 152        168
# Food, beverage and accommodation services                 975        858
# Insurance and financial services                        1,166      1,140
# Miscellaneous goods and services                          683        756
# Social transfers in kind (STiK)                         3,817      3,845
# Social transfers in kind (STiK): education              1,094      1,115
# Social transfers in kind (STiK): health                 2,029      2,027
# Social transfers in kind (STiK): other                    694        703
# Household actual final consumption                     17,361     17,165
# Change in pension entitlements                            320        433
# Household net saving                                    1,483      1,183
#
#                                                    Canada 1.8 Canada 1.9  ...  \
# Categories                                                                ...
# Year Quartile                                         Q1 2022    Q2 2022  ...
# Household disposable income                            13,367     13,696  ...
# Social transfers in kind (STiK): education              1,158      1,114  ...
# Social transfers in kind (STiK): health                 2,209      1,713  ...
# Social transfers in kind (STiK): other                    715        720  ...
# Adjusted household disposable income                   17,449     17,242  ...
# Household final consumption expenditure (HFCE)         12,458     14,133  ...
# Food and non-alcoholic beverages                        1,198      1,293  ...
# Alcoholic beverages and tobacco                           428        482  ...
# Clothing and footwear                                     464        648  ...
# Housing, water, electricity, gas and other fuels        3,162      3,169  ...
# Furnishings, household equipment and other good...        773        971  ...
# Health                                                    541        565  ...
# Transport                                               1,774      2,223  ...
# Communications                                            318        319  ...
# Recreation and culture                                  1,013      1,369  ...
# Education                                                 177        169  ...
# Food, beverage and accommodation services                 796      1,052  ...
# Insurance and financial services                        1,160      1,154  ...
# Miscellaneous goods and services                          654        718  ...
# Social transfers in kind (STiK)                         4,082      3,546  ...
# Social transfers in kind (STiK): education              1,158      1,114  ...
# Social transfers in kind (STiK): health                 2,209      1,713  ...
# Social transfers in kind (STiK): other                    715        720  ...
# Household actual final consumption                     16,540     17,679  ...
# Change in pension entitlements                            382        457  ...
# Household net saving                                    1,291         20  ...
#
#                                                    Nunavut 1.1 Nunavut 1.2  \
# Categories
# Year Quartile                                          Q2 2020     Q3 2020
# Household disposable income                             19,015      17,948
# Social transfers in kind (STiK): education               2,991       3,119
# Social transfers in kind (STiK): health                  7,512       7,774
# Social transfers in kind (STiK): other                   4,430       4,548
# Adjusted household disposable income                    33,947      33,389
# Household final consumption expenditure (HFCE)          11,165      12,228
# Food and non-alcoholic beverages                         1,887       1,882
# Alcoholic beverages and tobacco                            645         636
# Clothing and footwear                                      603         956
# Housing, water, electricity, gas and other fuels         4,332       4,348
# Furnishings, household equipment and other good...         753         843
# Health                                                     200         240
# Transport                                                  492         703
# Communications                                             267         270
# Recreation and culture                                     778         882
# Education                                                  134         121
# Food, beverage and accommodation services                  295         487
# Insurance and financial services                           322         319
# Miscellaneous goods and services                           458         540
# Social transfers in kind (STiK)                         14,932      15,441
# Social transfers in kind (STiK): education               2,991       3,119
# Social transfers in kind (STiK): health                  7,512       7,774
# Social transfers in kind (STiK): other                   4,430       4,548
# Household actual final consumption                      26,097      27,669
# Change in pension entitlements                           1,437       1,385
# Household net saving                                     9,287       7,105
#
#                                                    Nunavut 1.3 Nunavut 1.4  \
# Categories
# Year Quartile                                          Q4 2020     Q1 2021
# Household disposable income                             17,334      16,673
# Social transfers in kind (STiK): education               3,198       3,181
# Social transfers in kind (STiK): health                  7,920       7,706
# Social transfers in kind (STiK): other                   4,743       4,640
# Adjusted household disposable income                    33,195      32,199
# Household final consumption expenditure (HFCE)          12,262      10,565
# Food and non-alcoholic beverages                         1,920       1,694
# Alcoholic beverages and tobacco                            614         582
# Clothing and footwear                                    1,135         618
# Housing, water, electricity, gas and other fuels         4,263       4,083
# Furnishings, household equipment and other good...         896         653
# Health                                                     244         233
# Transport                                                  604         531
# Communications                                             270         247
# Recreation and culture                                     888         656
# Education                                                  134         130
# Food, beverage and accommodation services                  374         339
# Insurance and financial services                           331         317
# Miscellaneous goods and services                           590         483
# Social transfers in kind (STiK)                         15,861      15,526
# Social transfers in kind (STiK): education               3,198       3,181
# Social transfers in kind (STiK): health                  7,920       7,706
# Social transfers in kind (STiK): other                   4,743       4,640
# Household actual final consumption                      28,123      26,091
# Change in pension entitlements                           1,714       1,422
# Household net saving                                     6,786       7,529
#
#                                                    Nunavut 1.5 Nunavut 1.6  \
# Categories
# Year Quartile                                          Q2 2021     Q3 2021
# Household disposable income                             16,826      17,787
# Social transfers in kind (STiK): education               3,092       3,190
# Social transfers in kind (STiK): health                  7,289       7,603
# Social transfers in kind (STiK): other                   4,328       4,508
# Adjusted household disposable income                    31,535      33,087
# Household final consumption expenditure (HFCE)          11,466      12,319
# Food and non-alcoholic beverages                         1,748       1,769
# Alcoholic beverages and tobacco                            594         603
# Clothing and footwear                                      761       1,029
# Housing, water, electricity, gas and other fuels         4,156       4,287
# Furnishings, household equipment and other good...         806         821
# Health                                                     238         246
# Transport                                                  676         834
# Communications                                             245         257
# Recreation and culture                                     882         858
# Education                                                  127         119
# Food, beverage and accommodation services                  395         607
# Insurance and financial services                           322         329
# Miscellaneous goods and services                           516         559
# Social transfers in kind (STiK)                         14,709      15,300
# Social transfers in kind (STiK): education               3,092       3,190
# Social transfers in kind (STiK): health                  7,289       7,603
# Social transfers in kind (STiK): other                   4,328       4,508
# Household actual final consumption                      26,175      27,619
# Change in pension entitlements                           1,751       1,362
# Household net saving                                     7,111       6,830
#
#                                                    Nunavut 1.7 Nunavut 1.8  \
# Categories
# Year Quartile                                          Q4 2021     Q1 2022
# Household disposable income                             16,755      25,814
# Social transfers in kind (STiK): education               3,177       3,272
# Social transfers in kind (STiK): health                  7,519       9,057
# Social transfers in kind (STiK): other                   4,521       4,594
# Adjusted household disposable income                    31,972      42,736
# Household final consumption expenditure (HFCE)          12,086      11,703
# Food and non-alcoholic beverages                         1,728       1,724
# Alcoholic beverages and tobacco                            561         598
# Clothing and footwear                                    1,257         777
# Housing, water, electricity, gas and other fuels         4,087       4,442
# Furnishings, household equipment and other good...         835         678
# Health                                                     237         257
# Transport                                                  728         764
# Communications                                             256         256
# Recreation and culture                                     844         687
# Education                                                  132         143
# Food, beverage and accommodation services                  509         489
# Insurance and financial services                           324         341
# Miscellaneous goods and services                           589         548
# Social transfers in kind (STiK)                         15,217      16,922
# Social transfers in kind (STiK): education               3,177       3,272
# Social transfers in kind (STiK): health                  7,519       9,057
# Social transfers in kind (STiK): other                   4,521       4,594
# Household actual final consumption                      27,303      28,625
# Change in pension entitlements                           1,619       1,493
# Household net saving                                     6,288      15,604
#
#                                                    Nunavut 1.9 Nunavut 1.10
# Categories
# Year Quartile                                          Q2 2022      Q3 2022
# Household disposable income                             26,575       29,117
# Social transfers in kind (STiK): education               3,049        3,221
# Social transfers in kind (STiK): health                  8,169        8,908
# Social transfers in kind (STiK): other                   5,487        5,801
# Adjusted household disposable income                    43,281       47,048
# Household final consumption expenditure (HFCE)          13,103       13,223
# Food and non-alcoholic beverages                         1,848        1,877
# Alcoholic beverages and tobacco                            580          557
# Clothing and footwear                                    1,077        1,098
# Housing, water, electricity, gas and other fuels         4,471        4,545
# Furnishings, household equipment and other good...         870          826
# Health                                                     267          261
# Transport                                                1,018        1,096
# Communications                                             254          259
# Recreation and culture                                     958          896
# Education                                                  137          123
# Food, beverage and accommodation services                  689          761
# Insurance and financial services                           337          334
# Miscellaneous goods and services                           597          588
# Social transfers in kind (STiK)                         16,706       17,931
# Social transfers in kind (STiK): education               3,049        3,221
# Social transfers in kind (STiK): health                  8,169        8,908
# Social transfers in kind (STiK): other                   5,487        5,801
# Household actual final consumption                      29,809       31,154
# Change in pension entitlements                           1,701        1,330
# Household net saving                                    15,172       17,224
#
# [27 rows x 154 columns]

# %% [markdown]
# # Dividing the Data per Province
#
# Calculating values per year and the great total

# %% [markdown]
# CANADA

# %%
#Select olny the columns with values for Canada
canada_data = data_df.loc[:, ['Canada 1', 
                              'Canada 1.1', 
                              'Canada 1.2', 
                              'Canada 1.3', 
                              'Canada 1.4', 
                              'Canada 1.5', 
                              'Canada 1.6', 
                              'Canada 1.7', 
                              'Canada 1.8',
                              'Canada 1.9', 
                              'Canada 1.10']]


canada_data.head()
# Out:
#                                            Canada 1 Canada 1.1 Canada 1.2  \
# Categories
# Year Quartile                               Q1 2020    Q2 2020    Q3 2020
# Household disposable income                  12,182     13,880     14,223
# Social transfers in kind (STiK): education    1,134      1,040      1,100
# Social transfers in kind (STiK): health       1,736      1,744      1,815
# Social transfers in kind (STiK): other          717        659        682
#
#                                            Canada 1.3 Canada 1.4 Canada 1.5  \
# Categories
# Year Quartile                                 Q4 2020    Q1 2021    Q2 2021
# Household disposable income                    13,847     13,189     13,604
# Social transfers in kind (STiK): education      1,130      1,111      1,088
# Social transfers in kind (STiK): health         1,939      2,035      1,991
# Social transfers in kind (STiK): other            709        692        672
#
#                                            Canada 1.6 Canada 1.7 Canada 1.8  \
# Categories
# Year Quartile                                 Q3 2021    Q4 2021    Q1 2022
# Household disposable income                    14,707     14,070     13,367
# Social transfers in kind (STiK): education      1,094      1,115      1,158
# Social transfers in kind (STiK): health         2,029      2,027      2,209
# Social transfers in kind (STiK): other            694        703        715
#
#                                            Canada 1.9 Canada 1.10
# Categories
# Year Quartile                                 Q2 2022     Q3 2022
# Household disposable income                    13,696      14,940
# Social transfers in kind (STiK): education      1,114       1,194
# Social transfers in kind (STiK): health         1,713       1,863
# Social transfers in kind (STiK): other            720         763

# %%
#Calculate the yearly values for every category
CA_year = canada_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
CA_year = CA_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
CA_year = CA_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = CA_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = CA_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = CA_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
canada_peryear = pd.DataFrame({'Canada 2020': sum_col1, 'Canada 2021': sum_col2, 'Canada 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
canada_peryear['Total'] = canada_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
canada_peryear = canada_peryear.applymap(format_currency)

# Display the resulting dataframe
canada_peryear
# Out:
#                                                    Canada 2020 Canada 2021  \
# Categories
# Household disposable income                         $54,132.00  $55,570.00
# Social transfers in kind (STiK): education           $4,404.00   $4,408.00
# Social transfers in kind (STiK): health              $7,234.00   $8,082.00
# Social transfers in kind (STiK): other               $2,767.00   $2,761.00
# Adjusted household disposable income                $68,538.00  $70,822.00
# Household final consumption expenditure (HFCE)      $47,902.00  $51,065.00
# Food and non-alcoholic beverages                     $4,993.00   $4,989.00
# Alcoholic beverages and tobacco                      $1,973.00   $1,964.00
# Clothing and footwear                                $1,965.00   $2,260.00
# Housing, water, electricity, gas and other fuels    $11,798.00  $12,136.00
# Furnishings, household equipment and other good...   $3,300.00   $3,608.00
# Health                                               $1,918.00   $2,076.00
# Transport                                            $6,349.00   $7,192.00
# Communications                                       $1,293.00   $1,290.00
# Recreation and culture                               $4,235.00   $4,603.00
# Education                                              $639.00     $646.00
# Food, beverage and accommodation services            $2,691.00   $3,115.00
# Insurance and financial services                     $4,274.00   $4,550.00
# Miscellaneous goods and services                     $2,471.00   $2,638.00
# Social transfers in kind (STiK)                     $14,406.00  $15,252.00
# Social transfers in kind (STiK): education           $4,404.00   $4,408.00
# Social transfers in kind (STiK): health              $7,234.00   $8,082.00
# Social transfers in kind (STiK): other               $2,767.00   $2,761.00
# Household actual final consumption                  $62,308.00  $66,317.00
# Change in pension entitlements                       $1,521.00   $1,601.00
# Household net saving                                 $7,753.00   $6,105.00
#
#                                                    Canada 2022        Total
# Categories
# Household disposable income                         $42,003.00  $151,705.00
# Social transfers in kind (STiK): education           $3,466.00   $12,278.00
# Social transfers in kind (STiK): health              $5,785.00   $21,101.00
# Social transfers in kind (STiK): other               $2,198.00    $7,726.00
# Adjusted household disposable income                $53,451.00  $192,811.00
# Household final consumption expenditure (HFCE)      $40,643.00  $139,610.00
# Food and non-alcoholic beverages                     $3,794.00   $13,776.00
# Alcoholic beverages and tobacco                      $1,406.00    $5,343.00
# Clothing and footwear                                $1,766.00    $5,991.00
# Housing, water, electricity, gas and other fuels     $9,500.00   $33,434.00
# Furnishings, household equipment and other good...   $2,672.00    $9,580.00
# Health                                               $1,654.00    $5,648.00
# Transport                                            $6,191.00   $19,732.00
# Communications                                         $962.00    $3,545.00
# Recreation and culture                               $3,694.00   $12,532.00
# Education                                              $499.00    $1,784.00
# Food, beverage and accommodation services            $2,979.00    $8,785.00
# Insurance and financial services                     $3,445.00   $12,269.00
# Miscellaneous goods and services                     $2,080.00    $7,189.00
# Social transfers in kind (STiK)                     $11,448.00   $41,106.00
# Social transfers in kind (STiK): education           $3,466.00   $12,278.00
# Social transfers in kind (STiK): health              $5,785.00   $21,101.00
# Social transfers in kind (STiK): other               $2,198.00    $7,726.00
# Household actual final consumption                  $52,091.00  $180,716.00
# Change in pension entitlements                       $1,141.00    $4,263.00
# Household net saving                                 $2,502.00   $16,360.00

# %% [markdown]
# NEWFOUNDLAND AND LABRADOR

# %%
#Select olny the columns with values for Canada
NL_data = data_df.loc[:, ['Newfoundland and Labrador 1', 
           'Newfoundland and Labrador 1.1', 
           'Newfoundland and Labrador 1.2', 
           'Newfoundland and Labrador 1.3', 
           'Newfoundland and Labrador 1.4', 
           'Newfoundland and Labrador 1.5', 
           'Newfoundland and Labrador 1.6', 
           'Newfoundland and Labrador 1.7', 
           'Newfoundland and Labrador 1.8', 
           'Newfoundland and Labrador 1.9', 
           'Newfoundland and Labrador 1.10']]


NL_data.head()
# Out:
#                                            Newfoundland and Labrador 1  \
# Categories
# Year Quartile                                                  Q1 2020
# Household disposable income                                     10,866
# Social transfers in kind (STiK): education                       1,255
# Social transfers in kind (STiK): health                          2,003
# Social transfers in kind (STiK): other                             492
#
#                                            Newfoundland and Labrador 1.1  \
# Categories
# Year Quartile                                                    Q2 2020
# Household disposable income                                       12,936
# Social transfers in kind (STiK): education                         1,158
# Social transfers in kind (STiK): health                            1,897
# Social transfers in kind (STiK): other                               453
#
#                                            Newfoundland and Labrador 1.2  \
# Categories
# Year Quartile                                                    Q3 2020
# Household disposable income                                       12,636
# Social transfers in kind (STiK): education                         1,221
# Social transfers in kind (STiK): health                            2,005
# Social transfers in kind (STiK): other                               473
#
#                                            Newfoundland and Labrador 1.3  \
# Categories
# Year Quartile                                                    Q4 2020
# Household disposable income                                       12,481
# Social transfers in kind (STiK): education                         1,263
# Social transfers in kind (STiK): health                            2,064
# Social transfers in kind (STiK): other                               494
#
#                                            Newfoundland and Labrador 1.4  \
# Categories
# Year Quartile                                                    Q1 2021
# Household disposable income                                       13,025
# Social transfers in kind (STiK): education                         1,307
# Social transfers in kind (STiK): health                            2,282
# Social transfers in kind (STiK): other                               509
#
#                                            Newfoundland and Labrador 1.5  \
# Categories
# Year Quartile                                                    Q2 2021
# Household disposable income                                       13,384
# Social transfers in kind (STiK): education                         1,349
# Social transfers in kind (STiK): health                            2,146
# Social transfers in kind (STiK): other                               489
#
#                                            Newfoundland and Labrador 1.6  \
# Categories
# Year Quartile                                                    Q3 2021
# Household disposable income                                       13,980
# Social transfers in kind (STiK): education                         1,373
# Social transfers in kind (STiK): health                            2,211
# Social transfers in kind (STiK): other                               504
#
#                                            Newfoundland and Labrador 1.7  \
# Categories
# Year Quartile                                                    Q4 2021
# Household disposable income                                       13,135
# Social transfers in kind (STiK): education                         1,399
# Social transfers in kind (STiK): health                            2,235
# Social transfers in kind (STiK): other                               512
#
#                                            Newfoundland and Labrador 1.8  \
# Categories
# Year Quartile                                                    Q1 2022
# Household disposable income                                       11,744
# Social transfers in kind (STiK): education                         1,479
# Social transfers in kind (STiK): health                            2,499
# Social transfers in kind (STiK): other                               496
#
#                                            Newfoundland and Labrador 1.9  \
# Categories
# Year Quartile                                                    Q2 2022
# Household disposable income                                       12,837
# Social transfers in kind (STiK): education                         1,429
# Social transfers in kind (STiK): health                            2,169
# Social transfers in kind (STiK): other                               501
#
#                                            Newfoundland and Labrador 1.10
# Categories
# Year Quartile                                                     Q3 2022
# Household disposable income                                        13,390
# Social transfers in kind (STiK): education                          1,502
# Social transfers in kind (STiK): health                             2,356
# Social transfers in kind (STiK): other                                517

# %%
#Calculate the yearly values for every category
NL_year = NL_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
NL_year = NL_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
NL_year = NL_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = NL_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = NL_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = NL_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
NL_peryear = pd.DataFrame({'Newfoundland and Labrador 2020': sum_col1, 'Newfoundland and Labrador 2021': sum_col2, 'Newfoundland and Labrador 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
NL_peryear['Total'] = NL_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
NL_peryear = NL_peryear.applymap(format_currency)

# Display the resulting dataframe
NL_peryear
# Out:
#                                                    Newfoundland and Labrador 2020  \
# Categories
# Household disposable income                                            $48,919.00
# Social transfers in kind (STiK): education                              $4,897.00
# Social transfers in kind (STiK): health                                 $7,969.00
# Social transfers in kind (STiK): other                                  $1,912.00
# Adjusted household disposable income                                   $63,697.00
# Household final consumption expenditure (HFCE)                         $46,253.00
# Food and non-alcoholic beverages                                        $5,160.00
# Alcoholic beverages and tobacco                                         $2,793.00
# Clothing and footwear                                                   $1,829.00
# Housing, water, electricity, gas and other fuels                       $10,566.00
# Furnishings, household equipment and other good...                      $3,082.00
# Health                                                                  $1,712.00
# Transport                                                               $6,984.00
# Communications                                                          $1,524.00
# Recreation and culture                                                  $3,946.00
# Education                                                                 $377.00
# Food, beverage and accommodation services                               $2,373.00
# Insurance and financial services                                        $3,464.00
# Miscellaneous goods and services                                        $2,443.00
# Social transfers in kind (STiK)                                        $14,778.00
# Social transfers in kind (STiK): education                              $4,897.00
# Social transfers in kind (STiK): health                                 $7,969.00
# Social transfers in kind (STiK): other                                  $1,912.00
# Household actual final consumption                                     $61,031.00
# Change in pension entitlements                                            $-75.00
# Household net saving                                                    $2,592.00
#
#                                                    Newfoundland and Labrador 2021  \
# Categories
# Household disposable income                                            $53,524.00
# Social transfers in kind (STiK): education                              $5,428.00
# Social transfers in kind (STiK): health                                 $8,874.00
# Social transfers in kind (STiK): other                                  $2,014.00
# Adjusted household disposable income                                   $69,841.00
# Household final consumption expenditure (HFCE)                         $50,946.00
# Food and non-alcoholic beverages                                        $5,335.00
# Alcoholic beverages and tobacco                                         $2,879.00
# Clothing and footwear                                                   $2,181.00
# Housing, water, electricity, gas and other fuels                       $11,210.00
# Furnishings, household equipment and other good...                      $3,471.00
# Health                                                                  $1,890.00
# Transport                                                               $8,248.00
# Communications                                                          $1,572.00
# Recreation and culture                                                  $4,458.00
# Education                                                                 $395.00
# Food, beverage and accommodation services                               $2,848.00
# Insurance and financial services                                        $3,785.00
# Miscellaneous goods and services                                        $2,676.00
# Social transfers in kind (STiK)                                        $16,317.00
# Social transfers in kind (STiK): education                              $5,428.00
# Social transfers in kind (STiK): health                                 $8,874.00
# Social transfers in kind (STiK): other                                  $2,014.00
# Household actual final consumption                                     $67,263.00
# Change in pension entitlements                                            $-24.00
# Household net saving                                                    $2,553.00
#
#                                                    Newfoundland and Labrador 2022  \
# Categories
# Household disposable income                                            $37,971.00
# Social transfers in kind (STiK): education                              $4,410.00
# Social transfers in kind (STiK): health                                 $7,024.00
# Social transfers in kind (STiK): other                                  $1,514.00
# Adjusted household disposable income                                   $50,918.00
# Household final consumption expenditure (HFCE)                         $40,868.00
# Food and non-alcoholic beverages                                        $4,108.00
# Alcoholic beverages and tobacco                                         $2,094.00
# Clothing and footwear                                                   $1,720.00
# Housing, water, electricity, gas and other fuels                        $8,886.00
# Furnishings, household equipment and other good...                      $2,594.00
# Health                                                                  $1,523.00
# Transport                                                               $7,155.00
# Communications                                                          $1,182.00
# Recreation and culture                                                  $3,583.00
# Education                                                                 $306.00
# Food, beverage and accommodation services                               $2,715.00
# Insurance and financial services                                        $2,877.00
# Miscellaneous goods and services                                        $2,122.00
# Social transfers in kind (STiK)                                        $12,947.00
# Social transfers in kind (STiK): education                              $4,410.00
# Social transfers in kind (STiK): health                                 $7,024.00
# Social transfers in kind (STiK): other                                  $1,514.00
# Household actual final consumption                                     $53,815.00
# Change in pension entitlements                                           $-150.00
# Household net saving                                                   $-3,047.00
#
#                                                           Total
# Categories
# Household disposable income                         $140,414.00
# Social transfers in kind (STiK): education           $14,735.00
# Social transfers in kind (STiK): health              $23,867.00
# Social transfers in kind (STiK): other                $5,440.00
# Adjusted household disposable income                $184,456.00
# Household final consumption expenditure (HFCE)      $138,067.00
# Food and non-alcoholic beverages                     $14,603.00
# Alcoholic beverages and tobacco                       $7,766.00
# Clothing and footwear                                 $5,730.00
# Housing, water, electricity, gas and other fuels     $30,662.00
# Furnishings, household equipment and other good...    $9,147.00
# Health                                                $5,125.00
# Transport                                            $22,387.00
# Communications                                        $4,278.00
# Recreation and culture                               $11,987.00
# Education                                             $1,078.00
# Food, beverage and accommodation services             $7,936.00
# Insurance and financial services                     $10,126.00
# Miscellaneous goods and services                      $7,241.00
# Social transfers in kind (STiK)                      $44,042.00
# Social transfers in kind (STiK): education           $14,735.00
# Social transfers in kind (STiK): health              $23,867.00
# Social transfers in kind (STiK): other                $5,440.00
# Household actual final consumption                  $182,109.00
# Change in pension entitlements                         $-249.00
# Household net saving                                  $2,098.00

# %% [markdown]
# PRINCE EDWARD ISLAND

# %%
#Select olny the columns with values for Canada
PE_data = data_df.loc[:, ['Prince Edward Island 1', 
           'Prince Edward Island 1.1', 
           'Prince Edward Island 1.2', 
           'Prince Edward Island 1.3', 
           'Prince Edward Island 1.4', 
           'Prince Edward Island 1.5', 
           'Prince Edward Island 1.6', 
           'Prince Edward Island 1.7', 
           'Prince Edward Island 1.8', 
           'Prince Edward Island 1.9', 
           'Prince Edward Island 1.10']]


PE_data.head()
# Out:
#                                            Prince Edward Island 1  \
# Categories
# Year Quartile                                             Q1 2020
# Household disposable income                                 9,936
# Social transfers in kind (STiK): education                  1,040
# Social transfers in kind (STiK): health                     1,580
# Social transfers in kind (STiK): other                        546
#
#                                            Prince Edward Island 1.1  \
# Categories
# Year Quartile                                               Q2 2020
# Household disposable income                                  11,674
# Social transfers in kind (STiK): education                      939
# Social transfers in kind (STiK): health                       1,458
# Social transfers in kind (STiK): other                          502
#
#                                            Prince Edward Island 1.2  \
# Categories
# Year Quartile                                               Q3 2020
# Household disposable income                                  11,948
# Social transfers in kind (STiK): education                    1,016
# Social transfers in kind (STiK): health                       1,579
# Social transfers in kind (STiK): other                          532
#
#                                            Prince Edward Island 1.3  \
# Categories
# Year Quartile                                               Q4 2020
# Household disposable income                                  11,332
# Social transfers in kind (STiK): education                    1,021
# Social transfers in kind (STiK): health                       1,579
# Social transfers in kind (STiK): other                          543
#
#                                            Prince Edward Island 1.4  \
# Categories
# Year Quartile                                               Q1 2021
# Household disposable income                                  12,236
# Social transfers in kind (STiK): education                    1,132
# Social transfers in kind (STiK): health                       1,848
# Social transfers in kind (STiK): other                          560
#
#                                            Prince Edward Island 1.5  \
# Categories
# Year Quartile                                               Q2 2021
# Household disposable income                                  12,142
# Social transfers in kind (STiK): education                    1,073
# Social transfers in kind (STiK): health                       1,763
# Social transfers in kind (STiK): other                          535
#
#                                            Prince Edward Island 1.6  \
# Categories
# Year Quartile                                               Q3 2021
# Household disposable income                                  13,861
# Social transfers in kind (STiK): education                    1,094
# Social transfers in kind (STiK): health                       1,815
# Social transfers in kind (STiK): other                          546
#
#                                            Prince Edward Island 1.7  \
# Categories
# Year Quartile                                               Q4 2021
# Household disposable income                                  12,386
# Social transfers in kind (STiK): education                    1,074
# Social transfers in kind (STiK): health                       1,767
# Social transfers in kind (STiK): other                          538
#
#                                            Prince Edward Island 1.8  \
# Categories
# Year Quartile                                               Q1 2022
# Household disposable income                                  10,996
# Social transfers in kind (STiK): education                    1,138
# Social transfers in kind (STiK): health                       1,914
# Social transfers in kind (STiK): other                          589
#
#                                            Prince Edward Island 1.9  \
# Categories
# Year Quartile                                               Q2 2022
# Household disposable income                                  11,477
# Social transfers in kind (STiK): education                    1,085
# Social transfers in kind (STiK): health                       1,577
# Social transfers in kind (STiK): other                          619
#
#                                            Prince Edward Island 1.10
# Categories
# Year Quartile                                                Q3 2022
# Household disposable income                                   13,924
# Social transfers in kind (STiK): education                     1,156
# Social transfers in kind (STiK): health                        1,733
# Social transfers in kind (STiK): other                           643

# %%
#Calculate the yearly values for every category
PE_year = PE_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
PE_year = PE_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
PE_year = PE_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = PE_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = PE_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = PE_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
PE_peryear = pd.DataFrame({'Prince Edward Island 2020': sum_col1, 'Prince Edward Island 2021': sum_col2, 'Prince Edward Island 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
PE_peryear['Total'] = PE_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
PE_peryear = PE_peryear.applymap(format_currency)

# Display the resulting dataframe
PE_peryear
# Out:
#                                                    Prince Edward Island 2020  \
# Categories
# Household disposable income                                       $44,890.00
# Social transfers in kind (STiK): education                         $4,016.00
# Social transfers in kind (STiK): health                            $6,196.00
# Social transfers in kind (STiK): other                             $2,123.00
# Adjusted household disposable income                              $57,226.00
# Household final consumption expenditure (HFCE)                    $43,319.00
# Food and non-alcoholic beverages                                   $4,667.00
# Alcoholic beverages and tobacco                                    $2,126.00
# Clothing and footwear                                              $1,746.00
# Housing, water, electricity, gas and other fuels                  $10,248.00
# Furnishings, household equipment and other good...                 $3,024.00
# Health                                                             $1,707.00
# Transport                                                          $6,414.00
# Communications                                                     $1,378.00
# Recreation and culture                                             $3,778.00
# Education                                                            $676.00
# Food, beverage and accommodation services                          $2,024.00
# Insurance and financial services                                   $3,271.00
# Miscellaneous goods and services                                   $2,263.00
# Social transfers in kind (STiK)                                   $12,336.00
# Social transfers in kind (STiK): education                         $4,016.00
# Social transfers in kind (STiK): health                            $6,196.00
# Social transfers in kind (STiK): other                             $2,123.00
# Household actual final consumption                                $55,655.00
# Change in pension entitlements                                       $866.00
# Household net saving                                               $2,438.00
#
#                                                    Prince Edward Island 2021  \
# Categories
# Household disposable income                                       $50,625.00
# Social transfers in kind (STiK): education                         $4,373.00
# Social transfers in kind (STiK): health                            $7,193.00
# Social transfers in kind (STiK): other                             $2,179.00
# Adjusted household disposable income                              $64,369.00
# Household final consumption expenditure (HFCE)                    $51,669.00
# Food and non-alcoholic beverages                                   $5,224.00
# Alcoholic beverages and tobacco                                    $2,370.00
# Clothing and footwear                                              $2,239.00
# Housing, water, electricity, gas and other fuels                  $11,805.00
# Furnishings, household equipment and other good...                 $3,695.00
# Health                                                             $2,051.00
# Transport                                                          $8,217.00
# Communications                                                     $1,537.00
# Recreation and culture                                             $4,617.00
# Education                                                            $766.00
# Food, beverage and accommodation services                          $2,617.00
# Insurance and financial services                                   $3,862.00
# Miscellaneous goods and services                                   $2,668.00
# Social transfers in kind (STiK)                                   $13,744.00
# Social transfers in kind (STiK): education                         $4,373.00
# Social transfers in kind (STiK): health                            $7,193.00
# Social transfers in kind (STiK): other                             $2,179.00
# Household actual final consumption                                $65,413.00
# Change in pension entitlements                                       $857.00
# Household net saving                                                $-187.00
#
#                                                    Prince Edward Island 2022  \
# Categories
# Household disposable income                                       $36,397.00
# Social transfers in kind (STiK): education                         $3,379.00
# Social transfers in kind (STiK): health                            $5,224.00
# Social transfers in kind (STiK): other                             $1,851.00
# Adjusted household disposable income                              $46,850.00
# Household final consumption expenditure (HFCE)                    $34,340.00
# Food and non-alcoholic beverages                                   $3,329.00
# Alcoholic beverages and tobacco                                    $1,426.00
# Clothing and footwear                                              $1,472.00
# Housing, water, electricity, gas and other fuels                   $7,798.00
# Furnishings, household equipment and other good...                 $2,292.00
# Health                                                             $1,369.00
# Transport                                                          $5,879.00
# Communications                                                       $959.00
# Recreation and culture                                             $3,036.00
# Education                                                            $493.00
# Food, beverage and accommodation services                          $2,086.00
# Insurance and financial services                                   $2,434.00
# Miscellaneous goods and services                                   $1,766.00
# Social transfers in kind (STiK)                                   $10,453.00
# Social transfers in kind (STiK): education                         $3,379.00
# Social transfers in kind (STiK): health                            $5,224.00
# Social transfers in kind (STiK): other                             $1,851.00
# Household actual final consumption                                $44,793.00
# Change in pension entitlements                                       $578.00
# Household net saving                                               $2,635.00
#
#                                                           Total
# Categories
# Household disposable income                         $131,912.00
# Social transfers in kind (STiK): education           $11,768.00
# Social transfers in kind (STiK): health              $18,613.00
# Social transfers in kind (STiK): other                $6,153.00
# Adjusted household disposable income                $168,445.00
# Household final consumption expenditure (HFCE)      $129,328.00
# Food and non-alcoholic beverages                     $13,220.00
# Alcoholic beverages and tobacco                       $5,922.00
# Clothing and footwear                                 $5,457.00
# Housing, water, electricity, gas and other fuels     $29,851.00
# Furnishings, household equipment and other good...    $9,011.00
# Health                                                $5,127.00
# Transport                                            $20,510.00
# Communications                                        $3,874.00
# Recreation and culture                               $11,431.00
# Education                                             $1,935.00
# Food, beverage and accommodation services             $6,727.00
# Insurance and financial services                      $9,567.00
# Miscellaneous goods and services                      $6,697.00
# Social transfers in kind (STiK)                      $36,533.00
# Social transfers in kind (STiK): education           $11,768.00
# Social transfers in kind (STiK): health              $18,613.00
# Social transfers in kind (STiK): other                $6,153.00
# Household actual final consumption                  $165,861.00
# Change in pension entitlements                        $2,301.00
# Household net saving                                  $4,886.00

# %% [markdown]
# NOVA SCOTIA

# %%
#Select olny the columns with values for Canada
NS_data = data_df.loc[:, ['Nova Scotia 1', 
           'Nova Scotia 1.1', 
           'Nova Scotia 1.2', 
           'Nova Scotia 1.3', 
           'Nova Scotia 1.4', 
           'Nova Scotia 1.5', 
           'Nova Scotia 1.6', 
           'Nova Scotia 1.7', 
           'Nova Scotia 1.8', 
           'Nova Scotia 1.9', 
           'Nova Scotia 1.10']]


NS_data.head()
# Out:
#                                            Nova Scotia 1 Nova Scotia 1.1  \
# Categories
# Year Quartile                                    Q1 2020         Q2 2020
# Household disposable income                       10,595          12,453
# Social transfers in kind (STiK): education         1,053           1,034
# Social transfers in kind (STiK): health            2,058           1,905
# Social transfers in kind (STiK): other               655             634
#
#                                            Nova Scotia 1.2 Nova Scotia 1.3  \
# Categories
# Year Quartile                                      Q3 2020         Q4 2020
# Household disposable income                         12,306          11,928
# Social transfers in kind (STiK): education           1,100           1,122
# Social transfers in kind (STiK): health              2,018           2,058
# Social transfers in kind (STiK): other                 660             679
#
#                                            Nova Scotia 1.4 Nova Scotia 1.5  \
# Categories
# Year Quartile                                      Q1 2021         Q2 2021
# Household disposable income                         11,833          12,367
# Social transfers in kind (STiK): education           1,155           1,030
# Social transfers in kind (STiK): health              2,259           2,091
# Social transfers in kind (STiK): other                 671             659
#
#                                            Nova Scotia 1.6 Nova Scotia 1.7  \
# Categories
# Year Quartile                                      Q3 2021         Q4 2021
# Household disposable income                         12,967          12,193
# Social transfers in kind (STiK): education           1,049           1,039
# Social transfers in kind (STiK): health              2,149           2,142
# Social transfers in kind (STiK): other                 679             672
#
#                                            Nova Scotia 1.8 Nova Scotia 1.9  \
# Categories
# Year Quartile                                      Q1 2022         Q2 2022
# Household disposable income                         11,273          12,081
# Social transfers in kind (STiK): education           1,097           1,125
# Social transfers in kind (STiK): health              2,336           1,795
# Social transfers in kind (STiK): other                 709             641
#
#                                            Nova Scotia 1.10
# Categories
# Year Quartile                                       Q3 2022
# Household disposable income                          12,547
# Social transfers in kind (STiK): education            1,264
# Social transfers in kind (STiK): health               2,075
# Social transfers in kind (STiK): other                  691

# %%
#Calculate the yearly values for every category
NS_year = NS_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
NS_year = NS_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
NS_year = NS_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = NS_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = NS_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = NS_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
NS_peryear = pd.DataFrame({'Nova Scotia 2020': sum_col1, 'Nova Scotia 2021': sum_col2, 'Nova Scotia 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
NS_peryear['Total'] = NS_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
NS_peryear = NS_peryear.applymap(format_currency)

# Display the resulting dataframe
NS_peryear
# Out:
#                                                    Nova Scotia 2020  \
# Categories
# Household disposable income                              $47,282.00
# Social transfers in kind (STiK): education                $4,309.00
# Social transfers in kind (STiK): health                   $8,039.00
# Social transfers in kind (STiK): other                    $2,628.00
# Adjusted household disposable income                     $62,257.00
# Household final consumption expenditure (HFCE)           $45,493.00
# Food and non-alcoholic beverages                          $4,613.00
# Alcoholic beverages and tobacco                           $2,344.00
# Clothing and footwear                                     $1,603.00
# Housing, water, electricity, gas and other fuels         $12,023.00
# Furnishings, household equipment and other good...        $2,923.00
# Health                                                    $1,876.00
# Transport                                                 $6,044.00
# Communications                                            $1,411.00
# Recreation and culture                                    $4,026.00
# Education                                                   $557.00
# Food, beverage and accommodation services                 $2,120.00
# Insurance and financial services                          $3,323.00
# Miscellaneous goods and services                          $2,629.00
# Social transfers in kind (STiK)                          $14,975.00
# Social transfers in kind (STiK): education                $4,309.00
# Social transfers in kind (STiK): health                   $8,039.00
# Social transfers in kind (STiK): other                    $2,628.00
# Household actual final consumption                       $60,468.00
# Change in pension entitlements                            $1,547.00
# Household net saving                                      $3,336.00
#
#                                                    Nova Scotia 2021  \
# Categories
# Household disposable income                              $49,360.00
# Social transfers in kind (STiK): education                $4,273.00
# Social transfers in kind (STiK): health                   $8,641.00
# Social transfers in kind (STiK): other                    $2,681.00
# Adjusted household disposable income                     $64,955.00
# Household final consumption expenditure (HFCE)           $50,474.00
# Food and non-alcoholic beverages                          $4,811.00
# Alcoholic beverages and tobacco                           $2,429.00
# Clothing and footwear                                     $1,924.00
# Housing, water, electricity, gas and other fuels         $12,888.00
# Furnishings, household equipment and other good...        $3,321.00
# Health                                                    $2,114.00
# Transport                                                 $7,233.00
# Communications                                            $1,469.00
# Recreation and culture                                    $4,577.00
# Education                                                   $590.00
# Food, beverage and accommodation services                 $2,554.00
# Insurance and financial services                          $3,679.00
# Miscellaneous goods and services                          $2,887.00
# Social transfers in kind (STiK)                          $15,595.00
# Social transfers in kind (STiK): education                $4,273.00
# Social transfers in kind (STiK): health                   $8,641.00
# Social transfers in kind (STiK): other                    $2,681.00
# Household actual final consumption                       $66,069.00
# Change in pension entitlements                            $1,581.00
# Household net saving                                        $465.00
#
#                                                    Nova Scotia 2022  \
# Categories
# Household disposable income                              $35,901.00
# Social transfers in kind (STiK): education                $3,486.00
# Social transfers in kind (STiK): health                   $6,206.00
# Social transfers in kind (STiK): other                    $2,041.00
# Adjusted household disposable income                     $47,635.00
# Household final consumption expenditure (HFCE)           $38,363.00
# Food and non-alcoholic beverages                          $3,511.00
# Alcoholic beverages and tobacco                           $1,674.00
# Clothing and footwear                                     $1,443.00
# Housing, water, electricity, gas and other fuels          $9,734.00
# Furnishings, household equipment and other good...        $2,366.00
# Health                                                    $1,615.00
# Transport                                                 $5,904.00
# Communications                                            $1,047.00
# Recreation and culture                                    $3,471.00
# Education                                                   $435.00
# Food, beverage and accommodation services                 $2,327.00
# Insurance and financial services                          $2,663.00
# Miscellaneous goods and services                          $2,173.00
# Social transfers in kind (STiK)                          $11,734.00
# Social transfers in kind (STiK): education                $3,486.00
# Social transfers in kind (STiK): health                   $6,206.00
# Social transfers in kind (STiK): other                    $2,041.00
# Household actual final consumption                       $50,097.00
# Change in pension entitlements                            $1,136.00
# Household net saving                                     $-1,326.00
#
#                                                           Total
# Categories
# Household disposable income                         $132,543.00
# Social transfers in kind (STiK): education           $12,068.00
# Social transfers in kind (STiK): health              $22,886.00
# Social transfers in kind (STiK): other                $7,350.00
# Adjusted household disposable income                $174,847.00
# Household final consumption expenditure (HFCE)      $134,330.00
# Food and non-alcoholic beverages                     $12,935.00
# Alcoholic beverages and tobacco                       $6,447.00
# Clothing and footwear                                 $4,970.00
# Housing, water, electricity, gas and other fuels     $34,645.00
# Furnishings, household equipment and other good...    $8,610.00
# Health                                                $5,605.00
# Transport                                            $19,181.00
# Communications                                        $3,927.00
# Recreation and culture                               $12,074.00
# Education                                             $1,582.00
# Food, beverage and accommodation services             $7,001.00
# Insurance and financial services                      $9,665.00
# Miscellaneous goods and services                      $7,689.00
# Social transfers in kind (STiK)                      $42,304.00
# Social transfers in kind (STiK): education           $12,068.00
# Social transfers in kind (STiK): health              $22,886.00
# Social transfers in kind (STiK): other                $7,350.00
# Household actual final consumption                  $176,634.00
# Change in pension entitlements                        $4,264.00
# Household net saving                                  $2,475.00

# %% [markdown]
# NEW BRUNSWICK

# %%
#Select olny the columns with values for Canada
NB_data = data_df.loc[:, ['New Brunswick 1', 
           'New Brunswick 1.1', 
           'New Brunswick 1.2', 
           'New Brunswick 1.3', 
           'New Brunswick 1.4', 
           'New Brunswick 1.5', 
           'New Brunswick 1.6', 
           'New Brunswick 1.7', 
           'New Brunswick 1.8', 
           'New Brunswick 1.9', 
           'New Brunswick 1.10']]


NB_data.head()
# Out:
#                                            New Brunswick 1 New Brunswick 1.1  \
# Categories
# Year Quartile                                      Q1 2020           Q2 2020
# Household disposable income                         10,491            12,284
# Social transfers in kind (STiK): education           1,019               833
# Social transfers in kind (STiK): health              1,867             1,910
# Social transfers in kind (STiK): other                 685               499
#
#                                            New Brunswick 1.2  \
# Categories
# Year Quartile                                        Q3 2020
# Household disposable income                           12,101
# Social transfers in kind (STiK): education               829
# Social transfers in kind (STiK): health                1,885
# Social transfers in kind (STiK): other                   531
#
#                                            New Brunswick 1.3  \
# Categories
# Year Quartile                                        Q4 2020
# Household disposable income                           11,885
# Social transfers in kind (STiK): education               961
# Social transfers in kind (STiK): health                1,937
# Social transfers in kind (STiK): other                   554
#
#                                            New Brunswick 1.4  \
# Categories
# Year Quartile                                        Q1 2021
# Household disposable income                           11,983
# Social transfers in kind (STiK): education             1,140
# Social transfers in kind (STiK): health                2,174
# Social transfers in kind (STiK): other                   753
#
#                                            New Brunswick 1.5  \
# Categories
# Year Quartile                                        Q2 2021
# Household disposable income                           12,252
# Social transfers in kind (STiK): education               966
# Social transfers in kind (STiK): health                2,051
# Social transfers in kind (STiK): other                   516
#
#                                            New Brunswick 1.6  \
# Categories
# Year Quartile                                        Q3 2021
# Household disposable income                           12,992
# Social transfers in kind (STiK): education               846
# Social transfers in kind (STiK): health                1,925
# Social transfers in kind (STiK): other                   535
#
#                                            New Brunswick 1.7  \
# Categories
# Year Quartile                                        Q4 2021
# Household disposable income                           12,356
# Social transfers in kind (STiK): education               948
# Social transfers in kind (STiK): health                2,041
# Social transfers in kind (STiK): other                   562
#
#                                            New Brunswick 1.8  \
# Categories
# Year Quartile                                        Q1 2022
# Household disposable income                           11,389
# Social transfers in kind (STiK): education             1,415
# Social transfers in kind (STiK): health                1,889
# Social transfers in kind (STiK): other                   498
#
#                                            New Brunswick 1.9  \
# Categories
# Year Quartile                                        Q2 2022
# Household disposable income                           12,165
# Social transfers in kind (STiK): education             1,350
# Social transfers in kind (STiK): health                2,694
# Social transfers in kind (STiK): other                   703
#
#                                            New Brunswick 1.10
# Categories
# Year Quartile                                         Q3 2022
# Household disposable income                            13,054
# Social transfers in kind (STiK): education                745
# Social transfers in kind (STiK): health                 1,903
# Social transfers in kind (STiK): other                    567

# %%
#Calculate the yearly values for every category
NB_year = NB_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
NB_year = NB_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
NB_year = NB_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = NB_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = NB_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = NB_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
NB_peryear = pd.DataFrame({'New Brunswick 2020': sum_col1, 'New Brunswick 2021': sum_col2, 'New Brunswick 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
NB_peryear['Total'] = NB_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
NB_peryear = NB_peryear.applymap(format_currency)

# Display the resulting dataframe
NB_peryear
# Out:
#                                                    New Brunswick 2020  \
# Categories
# Household disposable income                                $46,761.00
# Social transfers in kind (STiK): education                  $3,642.00
# Social transfers in kind (STiK): health                     $7,599.00
# Social transfers in kind (STiK): other                      $2,269.00
# Adjusted household disposable income                       $60,272.00
# Household final consumption expenditure (HFCE)             $45,577.00
# Food and non-alcoholic beverages                            $4,791.00
# Alcoholic beverages and tobacco                             $2,181.00
# Clothing and footwear                                       $1,692.00
# Housing, water, electricity, gas and other fuels           $10,919.00
# Furnishings, household equipment and other good...          $3,379.00
# Health                                                      $2,027.00
# Transport                                                   $6,635.00
# Communications                                              $1,347.00
# Recreation and culture                                      $4,399.00
# Education                                                     $454.00
# Food, beverage and accommodation services                   $2,075.00
# Insurance and financial services                            $3,275.00
# Miscellaneous goods and services                            $2,399.00
# Social transfers in kind (STiK)                            $13,511.00
# Social transfers in kind (STiK): education                  $3,642.00
# Social transfers in kind (STiK): health                     $7,599.00
# Social transfers in kind (STiK): other                      $2,269.00
# Household actual final consumption                         $59,088.00
# Change in pension entitlements                              $1,255.00
# Household net saving                                        $2,439.00
#
#                                                    New Brunswick 2021  \
# Categories
# Household disposable income                                $49,583.00
# Social transfers in kind (STiK): education                  $3,900.00
# Social transfers in kind (STiK): health                     $8,191.00
# Social transfers in kind (STiK): other                      $2,366.00
# Adjusted household disposable income                       $64,041.00
# Household final consumption expenditure (HFCE)             $49,072.00
# Food and non-alcoholic beverages                            $4,833.00
# Alcoholic beverages and tobacco                             $2,193.00
# Clothing and footwear                                       $1,967.00
# Housing, water, electricity, gas and other fuels           $11,320.00
# Furnishings, household equipment and other good...          $3,718.00
# Health                                                      $2,203.00
# Transport                                                   $7,696.00
# Communications                                              $1,355.00
# Recreation and culture                                      $4,851.00
# Education                                                     $465.00
# Food, beverage and accommodation services                   $2,421.00
# Insurance and financial services                            $3,484.00
# Miscellaneous goods and services                            $2,564.00
# Social transfers in kind (STiK)                            $14,458.00
# Social transfers in kind (STiK): education                  $3,900.00
# Social transfers in kind (STiK): health                     $8,191.00
# Social transfers in kind (STiK): other                      $2,366.00
# Household actual final consumption                         $63,530.00
# Change in pension entitlements                              $1,333.00
# Household net saving                                        $1,844.00
#
#                                                    New Brunswick 2022  \
# Categories
# Household disposable income                                $36,608.00
# Social transfers in kind (STiK): education                  $3,510.00
# Social transfers in kind (STiK): health                     $6,486.00
# Social transfers in kind (STiK): other                      $1,768.00
# Adjusted household disposable income                       $48,372.00
# Household final consumption expenditure (HFCE)             $37,859.00
# Food and non-alcoholic beverages                            $3,586.00
# Alcoholic beverages and tobacco                             $1,538.00
# Clothing and footwear                                       $1,497.00
# Housing, water, electricity, gas and other fuels            $8,661.00
# Furnishings, household equipment and other good...          $2,681.00
# Health                                                      $1,710.00
# Transport                                                   $6,368.00
# Communications                                                $983.00
# Recreation and culture                                      $3,721.00
# Education                                                     $348.00
# Food, beverage and accommodation services                   $2,242.00
# Insurance and financial services                            $2,556.00
# Miscellaneous goods and services                            $1,967.00
# Social transfers in kind (STiK)                            $11,764.00
# Social transfers in kind (STiK): education                  $3,510.00
# Social transfers in kind (STiK): health                     $6,486.00
# Social transfers in kind (STiK): other                      $1,768.00
# Household actual final consumption                         $49,623.00
# Change in pension entitlements                                $944.00
# Household net saving                                         $-307.00
#
#                                                           Total
# Categories
# Household disposable income                         $132,952.00
# Social transfers in kind (STiK): education           $11,052.00
# Social transfers in kind (STiK): health              $22,276.00
# Social transfers in kind (STiK): other                $6,403.00
# Adjusted household disposable income                $172,685.00
# Household final consumption expenditure (HFCE)      $132,508.00
# Food and non-alcoholic beverages                     $13,210.00
# Alcoholic beverages and tobacco                       $5,912.00
# Clothing and footwear                                 $5,156.00
# Housing, water, electricity, gas and other fuels     $30,900.00
# Furnishings, household equipment and other good...    $9,778.00
# Health                                                $5,940.00
# Transport                                            $20,699.00
# Communications                                        $3,685.00
# Recreation and culture                               $12,971.00
# Education                                             $1,267.00
# Food, beverage and accommodation services             $6,738.00
# Insurance and financial services                      $9,315.00
# Miscellaneous goods and services                      $6,930.00
# Social transfers in kind (STiK)                      $39,733.00
# Social transfers in kind (STiK): education           $11,052.00
# Social transfers in kind (STiK): health              $22,276.00
# Social transfers in kind (STiK): other                $6,403.00
# Household actual final consumption                  $172,241.00
# Change in pension entitlements                        $3,532.00
# Household net saving                                  $3,976.00

# %% [markdown]
# QUEBEC

# %%
#Select olny the columns with values for Canada
QC_data = data_df.loc[:, ['Quebec 1', 
           'Quebec 1.1', 
           'Quebec 1.2', 
           'Quebec 1.3', 
           'Quebec 1.4', 
           'Quebec 1.5', 
           'Quebec 1.6', 
           'Quebec 1.7', 
           'Quebec 1.8', 
           'Quebec 1.9', 
           'Quebec 1.10']]


QC_data.head()
# Out:
#                                            Quebec 1 Quebec 1.1 Quebec 1.2  \
# Categories
# Year Quartile                               Q1 2020    Q2 2020    Q3 2020
# Household disposable income                  10,647     11,923     12,305
# Social transfers in kind (STiK): education    1,028        988      1,036
# Social transfers in kind (STiK): health       1,808      1,887      1,974
# Social transfers in kind (STiK): other          554        512        534
#
#                                            Quebec 1.3 Quebec 1.4 Quebec 1.5  \
# Categories
# Year Quartile                                 Q4 2020    Q1 2021    Q2 2021
# Household disposable income                    12,108     11,459     11,627
# Social transfers in kind (STiK): education      1,075      1,131      1,075
# Social transfers in kind (STiK): health         2,027      2,156      2,039
# Social transfers in kind (STiK): other            556        522        526
#
#                                            Quebec 1.6 Quebec 1.7 Quebec 1.8  \
# Categories
# Year Quartile                                 Q3 2021    Q4 2021    Q1 2022
# Household disposable income                    13,011     12,476     11,544
# Social transfers in kind (STiK): education      1,104      1,123      1,166
# Social transfers in kind (STiK): health         2,085      2,056      2,309
# Social transfers in kind (STiK): other            558        558        554
#
#                                            Quebec 1.9 Quebec 1.10
# Categories
# Year Quartile                                 Q2 2022     Q3 2022
# Household disposable income                    11,681      13,158
# Social transfers in kind (STiK): education      1,109       1,168
# Social transfers in kind (STiK): health         2,030       2,258
# Social transfers in kind (STiK): other            563         589

# %%
#Calculate the yearly values for every category
QC_year = QC_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
QC_year = QC_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
QC_year = QC_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = QC_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = QC_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = QC_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
QC_peryear = pd.DataFrame({'Quebec 2020': sum_col1, 'Quebec 2021': sum_col2, 'Quebec 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
QC_peryear['Total'] = QC_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
QC_peryear = QC_peryear.applymap(format_currency)

# Display the resulting dataframe
QC_peryear
# Out:
#                                                    Quebec 2020 Quebec 2021  \
# Categories
# Household disposable income                         $46,983.00  $48,573.00
# Social transfers in kind (STiK): education           $4,127.00   $4,433.00
# Social transfers in kind (STiK): health              $7,696.00   $8,336.00
# Social transfers in kind (STiK): other               $2,156.00   $2,164.00
# Adjusted household disposable income                $60,960.00  $63,504.00
# Household final consumption expenditure (HFCE)      $42,308.00  $45,538.00
# Food and non-alcoholic beverages                     $4,905.00   $4,944.00
# Alcoholic beverages and tobacco                      $1,907.00   $1,914.00
# Clothing and footwear                                $1,899.00   $2,202.00
# Housing, water, electricity, gas and other fuels     $9,216.00   $9,550.00
# Furnishings, household equipment and other good...   $3,083.00   $3,395.00
# Health                                               $1,905.00   $2,068.00
# Transport                                            $5,872.00   $6,728.00
# Communications                                       $1,107.00   $1,114.00
# Recreation and culture                               $3,546.00   $3,883.00
# Education                                              $419.00     $427.00
# Food, beverage and accommodation services            $2,435.00   $2,851.00
# Insurance and financial services                     $3,812.00   $4,091.00
# Miscellaneous goods and services                     $2,197.00   $2,375.00
# Social transfers in kind (STiK)                     $13,977.00  $14,931.00
# Social transfers in kind (STiK): education           $4,127.00   $4,433.00
# Social transfers in kind (STiK): health              $7,696.00   $8,336.00
# Social transfers in kind (STiK): other               $2,156.00   $2,164.00
# Household actual final consumption                  $56,285.00  $60,469.00
# Change in pension entitlements                       $3,209.00   $3,345.00
# Household net saving                                 $7,883.00   $6,379.00
#
#                                                    Quebec 2022        Total
# Categories
# Household disposable income                         $36,383.00  $131,939.00
# Social transfers in kind (STiK): education           $3,443.00   $12,003.00
# Social transfers in kind (STiK): health              $6,597.00   $22,629.00
# Social transfers in kind (STiK): other               $1,706.00    $6,026.00
# Adjusted household disposable income                $48,128.00  $172,592.00
# Household final consumption expenditure (HFCE)      $35,221.00  $123,067.00
# Food and non-alcoholic beverages                     $3,669.00   $13,518.00
# Alcoholic beverages and tobacco                      $1,341.00    $5,162.00
# Clothing and footwear                                $1,679.00    $5,780.00
# Housing, water, electricity, gas and other fuels     $7,299.00   $26,065.00
# Furnishings, household equipment and other good...   $2,453.00    $8,931.00
# Health                                               $1,609.00    $5,582.00
# Transport                                            $5,561.00   $18,161.00
# Communications                                         $809.00    $3,030.00
# Recreation and culture                               $3,006.00   $10,435.00
# Education                                              $322.00    $1,168.00
# Food, beverage and accommodation services            $2,633.00    $7,919.00
# Insurance and financial services                     $3,006.00   $10,909.00
# Miscellaneous goods and services                     $1,836.00    $6,408.00
# Social transfers in kind (STiK)                     $11,745.00   $40,653.00
# Social transfers in kind (STiK): education           $3,443.00   $12,003.00
# Social transfers in kind (STiK): health              $6,597.00   $22,629.00
# Social transfers in kind (STiK): other               $1,706.00    $6,026.00
# Household actual final consumption                  $46,966.00  $163,720.00
# Change in pension entitlements                       $2,503.00    $9,057.00
# Household net saving                                 $3,664.00   $17,926.00

# %% [markdown]
# ONTARIO

# %%
ON_data = data_df.loc[:, ['Ontario 1', 
           'Ontario 1.1', 
           'Ontario 1.2', 
           'Ontario 1.3', 
           'Ontario 1.4', 
           'Ontario 1.5', 
           'Ontario 1.6', 
           'Ontario 1.7', 
           'Ontario 1.8', 
           'Ontario 1.9', 
           'Ontario 1.10']]


ON_data.head()
# Out:
#                                            Ontario 1 Ontario 1.1 Ontario 1.2  \
# Categories
# Year Quartile                                Q1 2020     Q2 2020     Q3 2020
# Household disposable income                   12,432      14,386      14,468
# Social transfers in kind (STiK): education     1,190       1,053       1,123
# Social transfers in kind (STiK): health        1,550       1,583       1,607
# Social transfers in kind (STiK): other           805         740         778
#
#                                            Ontario 1.3 Ontario 1.4  \
# Categories
# Year Quartile                                  Q4 2020     Q1 2021
# Household disposable income                     14,047      13,507
# Social transfers in kind (STiK): education       1,131       1,074
# Social transfers in kind (STiK): health          1,751       1,896
# Social transfers in kind (STiK): other             801         779
#
#                                            Ontario 1.5 Ontario 1.6  \
# Categories
# Year Quartile                                  Q2 2021     Q3 2021
# Household disposable income                     14,062      14,924
# Social transfers in kind (STiK): education       1,053       1,054
# Social transfers in kind (STiK): health          1,928       1,957
# Social transfers in kind (STiK): other             737         757
#
#                                            Ontario 1.7 Ontario 1.8  \
# Categories
# Year Quartile                                  Q4 2021     Q1 2022
# Household disposable income                     14,327      13,839
# Social transfers in kind (STiK): education       1,072       1,138
# Social transfers in kind (STiK): health          1,939       2,107
# Social transfers in kind (STiK): other             768         790
#
#                                            Ontario 1.9 Ontario 1.10
# Categories
# Year Quartile                                  Q2 2022      Q3 2022
# Household disposable income                     14,251       15,250
# Social transfers in kind (STiK): education       1,100        1,247
# Social transfers in kind (STiK): health          1,228        1,358
# Social transfers in kind (STiK): other             782          853

# %%
#Calculate the yearly values for every category
ON_year = ON_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
ON_year = ON_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
ON_year = ON_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = ON_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = ON_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = ON_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
ON_peryear = pd.DataFrame({'Ontario 2020': sum_col1, 'Ontario 2021': sum_col2, 'Ontario 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
ON_peryear['Total'] = ON_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
ON_peryear = ON_peryear.applymap(format_currency)

# Display the resulting dataframe
ON_peryear
# Out:
#                                                    Ontario 2020 Ontario 2021  \
# Categories
# Household disposable income                          $55,333.00   $56,820.00
# Social transfers in kind (STiK): education            $4,497.00    $4,253.00
# Social transfers in kind (STiK): health               $6,491.00    $7,720.00
# Social transfers in kind (STiK): other                $3,124.00    $3,041.00
# Adjusted household disposable income                 $69,444.00   $71,833.00
# Household final consumption expenditure (HFCE)       $47,704.00   $50,059.00
# Food and non-alcoholic beverages                      $4,831.00    $4,746.00
# Alcoholic beverages and tobacco                       $1,734.00    $1,694.00
# Clothing and footwear                                 $1,997.00    $2,258.00
# Housing, water, electricity, gas and other fuels     $11,334.00   $11,468.00
# Furnishings, household equipment and other good...    $3,219.00    $3,467.00
# Health                                                $1,888.00    $2,012.00
# Transport                                             $6,558.00    $7,299.00
# Communications                                        $1,295.00    $1,271.00
# Recreation and culture                                $4,141.00    $4,415.00
# Education                                               $776.00      $773.00
# Food, beverage and accommodation services             $2,781.00    $3,168.00
# Insurance and financial services                      $4,560.00    $4,775.00
# Miscellaneous goods and services                      $2,589.00    $2,715.00
# Social transfers in kind (STiK)                      $14,111.00   $15,013.00
# Social transfers in kind (STiK): education            $4,497.00    $4,253.00
# Social transfers in kind (STiK): health               $6,491.00    $7,720.00
# Social transfers in kind (STiK): other                $3,124.00    $3,041.00
# Household actual final consumption                   $61,815.00   $65,072.00
# Change in pension entitlements                        $1,190.00    $1,292.00
# Household net saving                                  $8,818.00    $8,051.00
#
#                                                    Ontario 2022        Total
# Categories
# Household disposable income                          $43,340.00  $155,493.00
# Social transfers in kind (STiK): education            $3,485.00   $12,235.00
# Social transfers in kind (STiK): health               $4,693.00   $18,904.00
# Social transfers in kind (STiK): other                $2,425.00    $8,590.00
# Adjusted household disposable income                 $53,943.00  $195,220.00
# Household final consumption expenditure (HFCE)       $41,421.00  $139,184.00
# Food and non-alcoholic beverages                      $3,746.00   $13,323.00
# Alcoholic beverages and tobacco                       $1,260.00    $4,688.00
# Clothing and footwear                                 $1,828.00    $6,083.00
# Housing, water, electricity, gas and other fuels      $9,332.00   $32,134.00
# Furnishings, household equipment and other good...    $2,664.00    $9,350.00
# Health                                                $1,664.00    $5,564.00
# Transport                                             $6,549.00   $20,406.00
# Communications                                          $983.00    $3,549.00
# Recreation and culture                                $3,672.00   $12,228.00
# Education                                               $618.00    $2,167.00
# Food, beverage and accommodation services             $3,140.00    $9,089.00
# Insurance and financial services                      $3,747.00   $13,082.00
# Miscellaneous goods and services                      $2,218.00    $7,522.00
# Social transfers in kind (STiK)                      $10,603.00   $39,727.00
# Social transfers in kind (STiK): education            $3,485.00   $12,235.00
# Social transfers in kind (STiK): health               $4,693.00   $18,904.00
# Social transfers in kind (STiK): other                $2,425.00    $8,590.00
# Household actual final consumption                   $52,024.00  $178,911.00
# Change in pension entitlements                          $900.00    $3,382.00
# Household net saving                                  $2,820.00   $19,689.00

# %% [markdown]
# MANITOBA

# %%
MB_data = data_df.loc[:, ['Manitoba 1', 
           'Manitoba 1.1', 
           'Manitoba 1.2', 
           'Manitoba 1.3', 
           'Manitoba 1.4', 
           'Manitoba 1.5', 
           'Manitoba 1.6', 
           'Manitoba 1.7', 
           'Manitoba 1.8', 
           'Manitoba 1.9', 
           'Manitoba 1.10']]


MB_data.head()
# Out:
#                                            Manitoba 1 Manitoba 1.1  \
# Categories
# Year Quartile                                 Q1 2020      Q2 2020
# Household disposable income                    11,187       12,766
# Social transfers in kind (STiK): education      1,183        1,164
# Social transfers in kind (STiK): health         2,324        2,070
# Social transfers in kind (STiK): other          1,083          971
#
#                                            Manitoba 1.2 Manitoba 1.3  \
# Categories
# Year Quartile                                   Q3 2020      Q4 2020
# Household disposable income                      13,370       12,722
# Social transfers in kind (STiK): education        1,221        1,336
# Social transfers in kind (STiK): health           2,162        2,885
# Social transfers in kind (STiK): other              917          928
#
#                                            Manitoba 1.4 Manitoba 1.5  \
# Categories
# Year Quartile                                   Q1 2021      Q2 2021
# Household disposable income                      12,164       12,026
# Social transfers in kind (STiK): education        1,256        1,258
# Social transfers in kind (STiK): health           2,420        2,574
# Social transfers in kind (STiK): other              962          928
#
#                                            Manitoba 1.6 Manitoba 1.7  \
# Categories
# Year Quartile                                   Q3 2021      Q4 2021
# Household disposable income                      13,744       12,919
# Social transfers in kind (STiK): education        1,298        1,255
# Social transfers in kind (STiK): health           2,607        2,590
# Social transfers in kind (STiK): other              941          972
#
#                                            Manitoba 1.8 Manitoba 1.9  \
# Categories
# Year Quartile                                   Q1 2022      Q2 2022
# Household disposable income                      11,905       11,626
# Social transfers in kind (STiK): education        1,274        1,215
# Social transfers in kind (STiK): health           2,746        2,263
# Social transfers in kind (STiK): other            1,111          994
#
#                                            Manitoba 1.10
# Categories
# Year Quartile                                    Q3 2022
# Household disposable income                       14,262
# Social transfers in kind (STiK): education         1,369
# Social transfers in kind (STiK): health            2,617
# Social transfers in kind (STiK): other             1,046

# %%
#Calculate the yearly values for every category
MB_year = MB_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
MB_year = MB_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
MB_year = MB_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = MB_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = MB_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = MB_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
MB_peryear = pd.DataFrame({'Manitoba 2020': sum_col1, 'Manitoba 2021': sum_col2, 'Manitoba 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
MB_peryear['Total'] = MB_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
MB_peryear = MB_peryear.applymap(format_currency)

# Display the resulting dataframe
MB_peryear
# Out:
#                                                    Manitoba 2020  \
# Categories
# Household disposable income                           $50,045.00
# Social transfers in kind (STiK): education             $4,904.00
# Social transfers in kind (STiK): health                $9,441.00
# Social transfers in kind (STiK): other                 $3,899.00
# Adjusted household disposable income                  $68,290.00
# Household final consumption expenditure (HFCE)        $45,152.00
# Food and non-alcoholic beverages                       $4,533.00
# Alcoholic beverages and tobacco                        $2,191.00
# Clothing and footwear                                  $1,733.00
# Housing, water, electricity, gas and other fuels      $11,361.00
# Furnishings, household equipment and other good...     $3,233.00
# Health                                                 $1,733.00
# Transport                                              $5,808.00
# Communications                                         $1,242.00
# Recreation and culture                                 $4,527.00
# Education                                                $467.00
# Food, beverage and accommodation services              $2,393.00
# Insurance and financial services                       $3,630.00
# Miscellaneous goods and services                       $2,302.00
# Social transfers in kind (STiK)                       $18,245.00
# Social transfers in kind (STiK): education             $4,904.00
# Social transfers in kind (STiK): health                $9,441.00
# Social transfers in kind (STiK): other                 $3,899.00
# Household actual final consumption                    $63,397.00
# Change in pension entitlements                         $1,377.00
# Household net saving                                   $6,270.00
#
#                                                    Manitoba 2021  \
# Categories
# Household disposable income                           $50,853.00
# Social transfers in kind (STiK): education             $5,067.00
# Social transfers in kind (STiK): health               $10,191.00
# Social transfers in kind (STiK): other                 $3,803.00
# Adjusted household disposable income                  $69,916.00
# Household final consumption expenditure (HFCE)        $48,735.00
# Food and non-alcoholic beverages                       $4,592.00
# Alcoholic beverages and tobacco                        $2,211.00
# Clothing and footwear                                  $2,016.00
# Housing, water, electricity, gas and other fuels      $11,828.00
# Furnishings, household equipment and other good...     $3,576.00
# Health                                                 $1,910.00
# Transport                                              $6,687.00
# Communications                                         $1,256.00
# Recreation and culture                                 $5,012.00
# Education                                                $478.00
# Food, beverage and accommodation services              $2,807.00
# Insurance and financial services                       $3,895.00
# Miscellaneous goods and services                       $2,467.00
# Social transfers in kind (STiK)                       $19,063.00
# Social transfers in kind (STiK): education             $5,067.00
# Social transfers in kind (STiK): health               $10,191.00
# Social transfers in kind (STiK): other                 $3,803.00
# Household actual final consumption                    $67,798.00
# Change in pension entitlements                         $1,437.00
# Household net saving                                   $3,555.00
#
#                                                    Manitoba 2022        Total
# Categories
# Household disposable income                           $37,793.00  $138,691.00
# Social transfers in kind (STiK): education             $3,858.00   $13,829.00
# Social transfers in kind (STiK): health                $7,626.00   $27,258.00
# Social transfers in kind (STiK): other                 $3,151.00   $10,853.00
# Adjusted household disposable income                  $52,428.00  $190,634.00
# Household final consumption expenditure (HFCE)        $39,276.00  $133,163.00
# Food and non-alcoholic beverages                       $3,547.00   $12,672.00
# Alcoholic beverages and tobacco                        $1,612.00    $6,014.00
# Clothing and footwear                                  $1,598.00    $5,347.00
# Housing, water, electricity, gas and other fuels       $9,388.00   $32,577.00
# Furnishings, household equipment and other good...     $2,687.00    $9,496.00
# Health                                                 $1,546.00    $5,189.00
# Transport                                              $5,828.00   $18,323.00
# Communications                                           $948.00    $3,446.00
# Recreation and culture                                 $4,103.00   $13,642.00
# Education                                                $374.00    $1,319.00
# Food, beverage and accommodation services              $2,707.00    $7,907.00
# Insurance and financial services                       $2,982.00   $10,507.00
# Miscellaneous goods and services                       $1,957.00    $6,726.00
# Social transfers in kind (STiK)                       $14,635.00   $51,943.00
# Social transfers in kind (STiK): education             $3,858.00   $13,829.00
# Social transfers in kind (STiK): health                $7,626.00   $27,258.00
# Social transfers in kind (STiK): other                 $3,151.00   $10,853.00
# Household actual final consumption                    $53,911.00  $185,106.00
# Change in pension entitlements                         $1,018.00    $3,832.00
# Household net saving                                    $-466.00    $9,359.00

# %% [markdown]
# SASKATCHEWAN

# %%
SK_data = data_df.loc[:, ['Saskatchewan 1', 
           'Saskatchewan 1.1', 
           'Saskatchewan 1.2', 
           'Saskatchewan 1.3', 
           'Saskatchewan 1.4', 
           'Saskatchewan 1.5', 
           'Saskatchewan 1.6', 
           'Saskatchewan 1.7', 
           'Saskatchewan 1.8', 
           'Saskatchewan 1.9', 
           'Saskatchewan 1.10']]


SK_data.head()
# Out:
#                                            Saskatchewan 1 Saskatchewan 1.1  \
# Categories
# Year Quartile                                     Q1 2020          Q2 2020
# Household disposable income                        12,125           12,290
# Social transfers in kind (STiK): education          1,526            1,437
# Social transfers in kind (STiK): health             1,942            1,755
# Social transfers in kind (STiK): other                702              663
#
#                                            Saskatchewan 1.2 Saskatchewan 1.3  \
# Categories
# Year Quartile                                       Q3 2020          Q4 2020
# Household disposable income                          16,506           14,460
# Social transfers in kind (STiK): education            1,397            1,490
# Social transfers in kind (STiK): health               1,951            2,094
# Social transfers in kind (STiK): other                  676              709
#
#                                            Saskatchewan 1.4 Saskatchewan 1.5  \
# Categories
# Year Quartile                                       Q1 2021          Q2 2021
# Household disposable income                          12,783           13,002
# Social transfers in kind (STiK): education            1,521            1,510
# Social transfers in kind (STiK): health               2,069            1,911
# Social transfers in kind (STiK): other                  705              676
#
#                                            Saskatchewan 1.6 Saskatchewan 1.7  \
# Categories
# Year Quartile                                       Q3 2021          Q4 2021
# Household disposable income                          14,293           13,764
# Social transfers in kind (STiK): education            1,486            1,552
# Social transfers in kind (STiK): health               2,135            2,167
# Social transfers in kind (STiK): other                  681              699
#
#                                            Saskatchewan 1.8 Saskatchewan 1.9  \
# Categories
# Year Quartile                                       Q1 2022          Q2 2022
# Household disposable income                          12,696           12,891
# Social transfers in kind (STiK): education            1,537            1,461
# Social transfers in kind (STiK): health               2,264            1,981
# Social transfers in kind (STiK): other                  728              753
#
#                                            Saskatchewan 1.10
# Categories
# Year Quartile                                        Q3 2022
# Household disposable income                           14,425
# Social transfers in kind (STiK): education             1,536
# Social transfers in kind (STiK): health                2,263
# Social transfers in kind (STiK): other                   764

# %%
#Calculate the yearly values for every category
SK_year = SK_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
SK_year = SK_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
SK_year = SK_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = SK_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = SK_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = SK_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
SK_peryear = pd.DataFrame({'Saskatchewan 2020': sum_col1, 'Saskatchewan 2021': sum_col2, 'Saskatchewan 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
SK_peryear['Total'] = SK_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
SK_peryear = SK_peryear.applymap(format_currency)

# Display the resulting dataframe
SK_peryear
# Out:
#                                                    Saskatchewan 2020  \
# Categories
# Household disposable income                               $55,381.00
# Social transfers in kind (STiK): education                 $5,850.00
# Social transfers in kind (STiK): health                    $7,742.00
# Social transfers in kind (STiK): other                     $2,750.00
# Adjusted household disposable income                      $71,722.00
# Household final consumption expenditure (HFCE)            $47,975.00
# Food and non-alcoholic beverages                           $4,625.00
# Alcoholic beverages and tobacco                            $2,135.00
# Clothing and footwear                                      $1,912.00
# Housing, water, electricity, gas and other fuels          $12,872.00
# Furnishings, household equipment and other good...         $3,247.00
# Health                                                     $1,829.00
# Transport                                                  $6,282.00
# Communications                                             $1,362.00
# Recreation and culture                                     $4,562.00
# Education                                                    $454.00
# Food, beverage and accommodation services                  $2,532.00
# Insurance and financial services                           $3,885.00
# Miscellaneous goods and services                           $2,280.00
# Social transfers in kind (STiK)                           $16,341.00
# Social transfers in kind (STiK): education                 $5,850.00
# Social transfers in kind (STiK): health                    $7,742.00
# Social transfers in kind (STiK): other                     $2,750.00
# Household actual final consumption                        $64,316.00
# Change in pension entitlements                               $825.00
# Household net saving                                       $8,229.00
#
#                                                    Saskatchewan 2021  \
# Categories
# Household disposable income                               $53,842.00
# Social transfers in kind (STiK): education                 $6,069.00
# Social transfers in kind (STiK): health                    $8,282.00
# Social transfers in kind (STiK): other                     $2,761.00
# Adjusted household disposable income                      $70,953.00
# Household final consumption expenditure (HFCE)            $51,346.00
# Food and non-alcoholic beverages                           $4,637.00
# Alcoholic beverages and tobacco                            $2,135.00
# Clothing and footwear                                      $2,205.00
# Housing, water, electricity, gas and other fuels          $13,280.00
# Furnishings, household equipment and other good...         $3,550.00
# Health                                                     $1,976.00
# Transport                                                  $7,191.00
# Communications                                             $1,362.00
# Recreation and culture                                     $5,009.00
# Education                                                    $462.00
# Food, beverage and accommodation services                  $2,945.00
# Insurance and financial services                           $4,156.00
# Miscellaneous goods and services                           $2,436.00
# Social transfers in kind (STiK)                           $17,111.00
# Social transfers in kind (STiK): education                 $6,069.00
# Social transfers in kind (STiK): health                    $8,282.00
# Social transfers in kind (STiK): other                     $2,761.00
# Household actual final consumption                        $68,457.00
# Change in pension entitlements                               $939.00
# Household net saving                                       $3,435.00
#
#                                                    Saskatchewan 2022  \
# Categories
# Household disposable income                               $40,012.00
# Social transfers in kind (STiK): education                 $4,534.00
# Social transfers in kind (STiK): health                    $6,508.00
# Social transfers in kind (STiK): other                     $2,245.00
# Adjusted household disposable income                      $53,299.00
# Household final consumption expenditure (HFCE)            $42,749.00
# Food and non-alcoholic beverages                           $3,700.00
# Alcoholic beverages and tobacco                            $1,610.00
# Clothing and footwear                                      $1,803.00
# Housing, water, electricity, gas and other fuels          $10,906.00
# Furnishings, household equipment and other good...         $2,767.00
# Health                                                     $1,650.00
# Transport                                                  $6,384.00
# Communications                                             $1,063.00
# Recreation and culture                                     $4,268.00
# Education                                                    $373.00
# Food, beverage and accommodation services                  $2,933.00
# Insurance and financial services                           $3,286.00
# Miscellaneous goods and services                           $2,007.00
# Social transfers in kind (STiK)                           $13,287.00
# Social transfers in kind (STiK): education                 $4,534.00
# Social transfers in kind (STiK): health                    $6,508.00
# Social transfers in kind (STiK): other                     $2,245.00
# Household actual final consumption                        $56,036.00
# Change in pension entitlements                               $616.00
# Household net saving                                      $-2,122.00
#
#                                                           Total
# Categories
# Household disposable income                         $149,235.00
# Social transfers in kind (STiK): education           $16,453.00
# Social transfers in kind (STiK): health              $22,532.00
# Social transfers in kind (STiK): other                $7,756.00
# Adjusted household disposable income                $195,974.00
# Household final consumption expenditure (HFCE)      $142,070.00
# Food and non-alcoholic beverages                     $12,962.00
# Alcoholic beverages and tobacco                       $5,880.00
# Clothing and footwear                                 $5,920.00
# Housing, water, electricity, gas and other fuels     $37,058.00
# Furnishings, household equipment and other good...    $9,564.00
# Health                                                $5,455.00
# Transport                                            $19,857.00
# Communications                                        $3,787.00
# Recreation and culture                               $13,839.00
# Education                                             $1,289.00
# Food, beverage and accommodation services             $8,410.00
# Insurance and financial services                     $11,327.00
# Miscellaneous goods and services                      $6,723.00
# Social transfers in kind (STiK)                      $46,739.00
# Social transfers in kind (STiK): education           $16,453.00
# Social transfers in kind (STiK): health              $22,532.00
# Social transfers in kind (STiK): other                $7,756.00
# Household actual final consumption                  $188,809.00
# Change in pension entitlements                        $2,380.00
# Household net saving                                  $9,542.00

# %% [markdown]
# ALBERTA

# %%
AB_data = data_df.loc[:, ['Alberta 1', 
           'Alberta 1.1', 
           'Alberta 1.2', 
           'Alberta 1.3', 
           'Alberta 1.4', 
           'Alberta 1.5', 
           'Alberta 1.6', 
           'Alberta 1.7', 
           'Alberta 1.8', 
           'Alberta 1.9', 
           'Alberta 1.10']]


AB_data.head()
# Out:
#                                            Alberta 1 Alberta 1.1 Alberta 1.2  \
# Categories
# Year Quartile                                Q1 2020     Q2 2020     Q3 2020
# Household disposable income                   14,249      16,152      16,402
# Social transfers in kind (STiK): education     1,241       1,112       1,214
# Social transfers in kind (STiK): health        1,806       1,766       1,938
# Social transfers in kind (STiK): other           691         646         641
#
#                                            Alberta 1.3 Alberta 1.4  \
# Categories
# Year Quartile                                  Q4 2020     Q1 2021
# Household disposable income                     16,327      14,820
# Social transfers in kind (STiK): education       1,254       1,125
# Social transfers in kind (STiK): health          2,028       2,011
# Social transfers in kind (STiK): other             726         656
#
#                                            Alberta 1.5 Alberta 1.6  \
# Categories
# Year Quartile                                  Q2 2021     Q3 2021
# Household disposable income                     15,237      16,495
# Social transfers in kind (STiK): education       1,148       1,157
# Social transfers in kind (STiK): health          1,851       1,906
# Social transfers in kind (STiK): other             655         675
#
#                                            Alberta 1.7 Alberta 1.8  \
# Categories
# Year Quartile                                  Q4 2021     Q1 2022
# Household disposable income                     15,790      14,944
# Social transfers in kind (STiK): education       1,193       1,153
# Social transfers in kind (STiK): health          1,942       2,118
# Social transfers in kind (STiK): other             689         663
#
#                                            Alberta 1.9 Alberta 1.10
# Categories
# Year Quartile                                  Q2 2022      Q3 2022
# Household disposable income                     15,149       16,619
# Social transfers in kind (STiK): education       1,110        1,154
# Social transfers in kind (STiK): health          1,841        1,924
# Social transfers in kind (STiK): other             669          724

# %%
#Calculate the yearly values for every category
AB_year = AB_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
AB_year = AB_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
AB_year = AB_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = AB_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = AB_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = AB_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
AB_peryear = pd.DataFrame({'Alberta 2020': sum_col1, 'Alberta 2021': sum_col2, 'Alberta 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
AB_peryear['Total'] = AB_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
AB_peryear = AB_peryear.applymap(format_currency)

# Display the resulting dataframe
AB_peryear
# Out:
#                                                    Alberta 2020 Alberta 2021  \
# Categories
# Household disposable income                          $63,130.00   $62,342.00
# Social transfers in kind (STiK): education            $4,821.00    $4,623.00
# Social transfers in kind (STiK): health               $7,538.00    $7,710.00
# Social transfers in kind (STiK): other                $2,704.00    $2,675.00
# Adjusted household disposable income                 $78,193.00   $77,348.00
# Household final consumption expenditure (HFCE)       $52,329.00   $53,570.00
# Food and non-alcoholic beverages                      $5,217.00    $5,001.00
# Alcoholic beverages and tobacco                       $2,187.00    $2,086.00
# Clothing and footwear                                 $2,099.00    $2,315.00
# Housing, water, electricity, gas and other fuels     $13,387.00   $13,211.00
# Furnishings, household equipment and other good...    $3,565.00    $3,732.00
# Health                                                $2,067.00    $2,142.00
# Transport                                             $6,634.00    $7,191.00
# Communications                                        $1,438.00    $1,376.00
# Recreation and culture                                $5,052.00    $5,290.00
# Education                                               $632.00      $612.00
# Food, beverage and accommodation services             $3,017.00    $3,350.00
# Insurance and financial services                      $4,606.00    $4,746.00
# Miscellaneous goods and services                      $2,429.00    $2,515.00
# Social transfers in kind (STiK)                      $15,063.00   $15,006.00
# Social transfers in kind (STiK): education            $4,821.00    $4,623.00
# Social transfers in kind (STiK): health               $7,538.00    $7,710.00
# Social transfers in kind (STiK): other                $2,704.00    $2,675.00
# Household actual final consumption                   $67,392.00   $68,576.00
# Change in pension entitlements                           $98.00        $0.00
# Household net saving                                 $10,899.00    $8,774.00
#
#                                                    Alberta 2022        Total
# Categories
# Household disposable income                          $46,712.00  $172,184.00
# Social transfers in kind (STiK): education            $3,417.00   $12,861.00
# Social transfers in kind (STiK): health               $5,883.00   $21,131.00
# Social transfers in kind (STiK): other                $2,056.00    $7,435.00
# Adjusted household disposable income                 $58,068.00  $213,609.00
# Household final consumption expenditure (HFCE)       $44,912.00  $150,811.00
# Food and non-alcoholic beverages                      $4,006.00   $14,224.00
# Alcoholic beverages and tobacco                       $1,577.00    $5,850.00
# Clothing and footwear                                 $1,898.00    $6,312.00
# Housing, water, electricity, gas and other fuels     $10,894.00   $37,492.00
# Furnishings, household equipment and other good...    $2,907.00   $10,204.00
# Health                                                $1,788.00    $5,997.00
# Transport                                             $6,562.00   $20,387.00
# Communications                                        $1,077.00    $3,891.00
# Recreation and culture                                $4,490.00   $14,832.00
# Education                                               $496.00    $1,740.00
# Food, beverage and accommodation services             $3,362.00    $9,729.00
# Insurance and financial services                      $3,771.00   $13,123.00
# Miscellaneous goods and services                      $2,083.00    $7,027.00
# Social transfers in kind (STiK)                      $11,356.00   $41,425.00
# Social transfers in kind (STiK): education            $3,417.00   $12,861.00
# Social transfers in kind (STiK): health               $5,883.00   $21,131.00
# Social transfers in kind (STiK): other                $2,056.00    $7,435.00
# Household actual final consumption                   $56,268.00  $192,236.00
# Change in pension entitlements                         $-118.00      $-20.00
# Household net saving                                  $1,681.00   $21,354.00

# %% [markdown]
# BRITISH COLUMBIA

# %%
BC_data = data_df.loc[:, ['British Columbia 1', 
           'British Columbia 1.1', 
           'British Columbia 1.2', 
           'British Columbia 1.3', 
           'British Columbia 1.4', 
           'British Columbia 1.5', 
           'British Columbia 1.6', 
           'British Columbia 1.7', 
           'British Columbia 1.8', 
           'British Columbia 1.9', 
           'British Columbia 1.10']]


BC_data.head()
# Out:
#                                            British Columbia 1  \
# Categories
# Year Quartile                                         Q1 2020
# Household disposable income                            13,305
# Social transfers in kind (STiK): education                969
# Social transfers in kind (STiK): health                 1,705
# Social transfers in kind (STiK): other                    667
#
#                                            British Columbia 1.1  \
# Categories
# Year Quartile                                           Q2 2020
# Household disposable income                              15,089
# Social transfers in kind (STiK): education                  915
# Social transfers in kind (STiK): health                   1,722
# Social transfers in kind (STiK): other                      612
#
#                                            British Columbia 1.2  \
# Categories
# Year Quartile                                           Q3 2020
# Household disposable income                              15,530
# Social transfers in kind (STiK): education                  962
# Social transfers in kind (STiK): health                   1,780
# Social transfers in kind (STiK): other                      638
#
#                                            British Columbia 1.3  \
# Categories
# Year Quartile                                           Q4 2020
# Household disposable income                              15,142
# Social transfers in kind (STiK): education                  981
# Social transfers in kind (STiK): health                   1,878
# Social transfers in kind (STiK): other                      641
#
#                                            British Columbia 1.4  \
# Categories
# Year Quartile                                           Q1 2021
# Household disposable income                              14,609
# Social transfers in kind (STiK): education                  980
# Social transfers in kind (STiK): health                   1,985
# Social transfers in kind (STiK): other                      652
#
#                                            British Columbia 1.5  \
# Categories
# Year Quartile                                           Q2 2021
# Household disposable income                              15,249
# Social transfers in kind (STiK): education                  999
# Social transfers in kind (STiK): health                   1,971
# Social transfers in kind (STiK): other                      686
#
#                                            British Columbia 1.6  \
# Categories
# Year Quartile                                           Q3 2021
# Household disposable income                              16,407
# Social transfers in kind (STiK): education                  985
# Social transfers in kind (STiK): health                   1,985
# Social transfers in kind (STiK): other                      701
#
#                                            British Columbia 1.7  \
# Categories
# Year Quartile                                           Q4 2021
# Household disposable income                              15,637
# Social transfers in kind (STiK): education                1,007
# Social transfers in kind (STiK): health                   2,018
# Social transfers in kind (STiK): other                      707
#
#                                            British Columbia 1.8  \
# Categories
# Year Quartile                                           Q1 2022
# Household disposable income                              15,065
# Social transfers in kind (STiK): education                1,000
# Social transfers in kind (STiK): health                   2,176
# Social transfers in kind (STiK): other                      723
#
#                                            British Columbia 1.9  \
# Categories
# Year Quartile                                           Q2 2022
# Household disposable income                              15,504
# Social transfers in kind (STiK): education                  965
# Social transfers in kind (STiK): health                   1,950
# Social transfers in kind (STiK): other                      756
#
#                                            British Columbia 1.10
# Categories
# Year Quartile                                            Q3 2022
# Household disposable income                               16,652
# Social transfers in kind (STiK): education                   995
# Social transfers in kind (STiK): health                    2,115
# Social transfers in kind (STiK): other                       775

# %%
#Calculate the yearly values for every category
BC_year = BC_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
BC_year = BC_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
BC_year = BC_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = BC_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = BC_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = BC_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
BC_peryear = pd.DataFrame({'British Columbia 2020': sum_col1, 'British Columbia 2021': sum_col2, 'British Columbia 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
BC_peryear['Total'] = BC_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
BC_peryear = BC_peryear.applymap(format_currency)

# Display the resulting dataframe
BC_peryear
# Out:
#                                                    British Columbia 2020  \
# Categories
# Household disposable income                                   $59,066.00
# Social transfers in kind (STiK): education                     $3,827.00
# Social transfers in kind (STiK): health                        $7,085.00
# Social transfers in kind (STiK): other                         $2,558.00
# Adjusted household disposable income                          $72,534.00
# Household final consumption expenditure (HFCE)                $55,968.00
# Food and non-alcoholic beverages                               $5,672.00
# Alcoholic beverages and tobacco                                $2,265.00
# Clothing and footwear                                          $2,086.00
# Housing, water, electricity, gas and other fuels              $16,178.00
# Furnishings, household equipment and other good...             $3,805.00
# Health                                                         $2,007.00
# Transport                                                      $6,458.00
# Communications                                                 $1,425.00
# Recreation and culture                                         $4,893.00
# Education                                                        $793.00
# Food, beverage and accommodation services                      $2,960.00
# Insurance and financial services                               $4,715.00
# Miscellaneous goods and services                               $2,712.00
# Social transfers in kind (STiK)                               $13,468.00
# Social transfers in kind (STiK): education                     $3,827.00
# Social transfers in kind (STiK): health                        $7,085.00
# Social transfers in kind (STiK): other                         $2,558.00
# Household actual final consumption                            $69,436.00
# Change in pension entitlements                                 $1,147.00
# Household net saving                                           $4,244.00
#
#                                                    British Columbia 2021  \
# Categories
# Household disposable income                                   $61,902.00
# Social transfers in kind (STiK): education                     $3,971.00
# Social transfers in kind (STiK): health                        $7,959.00
# Social transfers in kind (STiK): other                         $2,746.00
# Adjusted household disposable income                          $76,579.00
# Household final consumption expenditure (HFCE)                $62,170.00
# Food and non-alcoholic beverages                               $5,915.00
# Alcoholic beverages and tobacco                                $2,347.00
# Clothing and footwear                                          $2,502.00
# Housing, water, electricity, gas and other fuels              $17,367.00
# Furnishings, household equipment and other good...             $4,350.00
# Health                                                         $2,288.00
# Transport                                                      $7,615.00
# Communications                                                 $1,485.00
# Recreation and culture                                         $5,585.00
# Education                                                        $837.00
# Food, beverage and accommodation services                      $3,580.00
# Insurance and financial services                               $5,274.00
# Miscellaneous goods and services                               $3,027.00
# Social transfers in kind (STiK)                               $14,677.00
# Social transfers in kind (STiK): education                     $3,971.00
# Social transfers in kind (STiK): health                        $7,959.00
# Social transfers in kind (STiK): other                         $2,746.00
# Household actual final consumption                            $76,847.00
# Change in pension entitlements                                 $1,239.00
# Household net saving                                             $970.00
#
#                                                    British Columbia 2022  \
# Categories
# Household disposable income                                   $47,221.00
# Social transfers in kind (STiK): education                     $2,960.00
# Social transfers in kind (STiK): health                        $6,241.00
# Social transfers in kind (STiK): other                         $2,254.00
# Adjusted household disposable income                          $58,677.00
# Household final consumption expenditure (HFCE)                $44,916.00
# Food and non-alcoholic beverages                               $4,087.00
# Alcoholic beverages and tobacco                                $1,532.00
# Clothing and footwear                                          $1,777.00
# Housing, water, electricity, gas and other fuels              $12,365.00
# Furnishings, household equipment and other good...             $2,926.00
# Health                                                         $1,656.00
# Transport                                                      $5,954.00
# Communications                                                 $1,003.00
# Recreation and culture                                         $4,096.00
# Education                                                        $586.00
# Food, beverage and accommodation services                      $3,154.00
# Insurance and financial services                               $3,624.00
# Miscellaneous goods and services                               $2,157.00
# Social transfers in kind (STiK)                               $11,456.00
# Social transfers in kind (STiK): education                     $2,960.00
# Social transfers in kind (STiK): health                        $6,241.00
# Social transfers in kind (STiK): other                         $2,254.00
# Household actual final consumption                            $56,372.00
# Change in pension entitlements                                   $882.00
# Household net saving                                           $3,187.00
#
#                                                           Total
# Categories
# Household disposable income                         $168,189.00
# Social transfers in kind (STiK): education           $10,758.00
# Social transfers in kind (STiK): health              $21,285.00
# Social transfers in kind (STiK): other                $7,558.00
# Adjusted household disposable income                $207,790.00
# Household final consumption expenditure (HFCE)      $163,054.00
# Food and non-alcoholic beverages                     $15,674.00
# Alcoholic beverages and tobacco                       $6,144.00
# Clothing and footwear                                 $6,365.00
# Housing, water, electricity, gas and other fuels     $45,910.00
# Furnishings, household equipment and other good...   $11,081.00
# Health                                                $5,951.00
# Transport                                            $20,027.00
# Communications                                        $3,913.00
# Recreation and culture                               $14,574.00
# Education                                             $2,216.00
# Food, beverage and accommodation services             $9,694.00
# Insurance and financial services                     $13,613.00
# Miscellaneous goods and services                      $7,896.00
# Social transfers in kind (STiK)                      $39,601.00
# Social transfers in kind (STiK): education           $10,758.00
# Social transfers in kind (STiK): health              $21,285.00
# Social transfers in kind (STiK): other                $7,558.00
# Household actual final consumption                  $202,655.00
# Change in pension entitlements                        $3,268.00
# Household net saving                                  $8,401.00

# %% [markdown]
# YUKON

# %%
YT_data = data_df.loc[:, ['Yukon 1', 
           'Yukon 1.1', 
           'Yukon 1.2', 
           'Yukon 1.3', 
           'Yukon 1.4', 
           'Yukon 1.5', 
           'Yukon 1.6', 
           'Yukon 1.7', 
           'Yukon 1.8', 
           'Yukon 1.9', 
           'Yukon 1.10']]


YT_data.head()
# Out:
#                                             Yukon 1 Yukon 1.1 Yukon 1.2  \
# Categories
# Year Quartile                               Q1 2020   Q2 2020   Q3 2020
# Household disposable income                  15,992    17,917    17,879
# Social transfers in kind (STiK): education    1,719     1,496     1,585
# Social transfers in kind (STiK): health       2,995     2,913     3,093
# Social transfers in kind (STiK): other        1,852     1,847     1,913
#
#                                            Yukon 1.3 Yukon 1.4 Yukon 1.5  \
# Categories
# Year Quartile                                Q4 2020   Q1 2021   Q2 2021
# Household disposable income                   17,909    18,010    18,943
# Social transfers in kind (STiK): education     1,621     1,741     1,694
# Social transfers in kind (STiK): health        3,145     3,115     2,942
# Social transfers in kind (STiK): other         1,993     2,056     1,934
#
#                                            Yukon 1.6 Yukon 1.7 Yukon 1.8  \
# Categories
# Year Quartile                                Q3 2021   Q4 2021   Q1 2022
# Household disposable income                   19,742    18,892    17,976
# Social transfers in kind (STiK): education     1,742     1,746     1,804
# Social transfers in kind (STiK): health        3,059     3,036     3,777
# Social transfers in kind (STiK): other         2,001     2,015     2,065
#
#                                            Yukon 1.9 Yukon 1.10
# Categories
# Year Quartile                                Q2 2022    Q3 2022
# Household disposable income                   19,783     21,654
# Social transfers in kind (STiK): education     1,713      1,793
# Social transfers in kind (STiK): health        3,360      3,630
# Social transfers in kind (STiK): other         2,051      2,138

# %%
#Calculate the yearly values for every category
YT_year = YT_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
YT_year = YT_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
YT_year = YT_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = YT_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = YT_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = YT_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
YT_peryear = pd.DataFrame({'Yukon 2020': sum_col1, 'Yukon 2021': sum_col2, 'Yukon 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
YT_peryear['Total'] = YT_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
YT_peryear = YT_peryear.applymap(format_currency)

# Display the resulting dataframe
YT_peryear
# Out:
#                                                     Yukon 2020   Yukon 2021  \
# Categories
# Household disposable income                         $69,697.00   $75,587.00
# Social transfers in kind (STiK): education           $6,421.00    $6,923.00
# Social transfers in kind (STiK): health             $12,146.00   $12,152.00
# Social transfers in kind (STiK): other               $7,605.00    $8,006.00
# Adjusted household disposable income                $95,872.00  $102,667.00
# Household final consumption expenditure (HFCE)      $54,579.00   $57,504.00
# Food and non-alcoholic beverages                     $5,637.00    $5,583.00
# Alcoholic beverages and tobacco                      $2,671.00    $2,637.00
# Clothing and footwear                                $1,204.00    $1,370.00
# Housing, water, electricity, gas and other fuels    $18,746.00   $19,090.00
# Furnishings, household equipment and other good...   $3,058.00    $3,320.00
# Health                                               $1,330.00    $1,450.00
# Transport                                            $5,883.00    $6,581.00
# Communications                                       $1,258.00    $1,245.00
# Recreation and culture                               $5,184.00    $5,662.00
# Education                                              $294.00      $294.00
# Food, beverage and accommodation services            $4,002.00    $4,630.00
# Insurance and financial services                     $3,032.00    $3,201.00
# Miscellaneous goods and services                     $2,281.00    $2,441.00
# Social transfers in kind (STiK)                     $26,175.00   $27,080.00
# Social transfers in kind (STiK): education           $6,421.00    $6,923.00
# Social transfers in kind (STiK): health             $12,146.00   $12,152.00
# Social transfers in kind (STiK): other               $7,605.00    $8,006.00
# Household actual final consumption                  $80,754.00   $84,584.00
# Change in pension entitlements                       $1,059.00      $777.00
# Household net saving                                $16,176.00   $18,861.00
#
#                                                     Yukon 2022        Total
# Categories
# Household disposable income                         $59,413.00  $204,697.00
# Social transfers in kind (STiK): education           $5,310.00   $18,654.00
# Social transfers in kind (STiK): health             $10,767.00   $35,065.00
# Social transfers in kind (STiK): other               $6,254.00   $21,865.00
# Adjusted household disposable income                $81,743.00  $280,282.00
# Household final consumption expenditure (HFCE)      $41,864.00  $153,947.00
# Food and non-alcoholic beverages                     $3,822.00   $15,042.00
# Alcoholic beverages and tobacco                      $1,707.00    $7,015.00
# Clothing and footwear                                  $965.00    $3,539.00
# Housing, water, electricity, gas and other fuels    $13,486.00   $51,322.00
# Furnishings, household equipment and other good...   $2,227.00    $8,605.00
# Health                                               $1,042.00    $3,822.00
# Transport                                            $5,453.00   $17,917.00
# Communications                                         $833.00    $3,336.00
# Recreation and culture                               $4,064.00   $14,910.00
# Education                                              $205.00      $793.00
# Food, beverage and accommodation services            $4,167.00   $12,799.00
# Insurance and financial services                     $2,171.00    $8,404.00
# Miscellaneous goods and services                     $1,721.00    $6,443.00
# Social transfers in kind (STiK)                     $22,330.00   $75,585.00
# Social transfers in kind (STiK): education           $5,310.00   $18,654.00
# Social transfers in kind (STiK): health             $10,767.00   $35,065.00
# Social transfers in kind (STiK): other               $6,254.00   $21,865.00
# Household actual final consumption                  $64,194.00  $229,532.00
# Change in pension entitlements                         $406.00    $2,242.00
# Household net saving                                $17,954.00   $52,991.00

# %% [markdown]
# NORTHWEST TERRITORIES

# %%
NT_data = data_df.loc[:, ['Northwest Territories 1', 
           'Northwest Territories 1.1', 
           'Northwest Territories 1.2', 
           'Northwest Territories 1.3', 
           'Northwest Territories 1.4', 
           'Northwest Territories 1.5', 
           'Northwest Territories 1.6', 
           'Northwest Territories 1.7', 
           'Northwest Territories 1.8', 
           'Northwest Territories 1.9', 
           'Northwest Territories 1.10']]


NT_data.head()
# Out:
#                                            Northwest Territories 1  \
# Categories
# Year Quartile                                              Q1 2020
# Household disposable income                                 17,467
# Social transfers in kind (STiK): education                   2,610
# Social transfers in kind (STiK): health                      5,120
# Social transfers in kind (STiK): other                       3,688
#
#                                            Northwest Territories 1.1  \
# Categories
# Year Quartile                                                Q2 2020
# Household disposable income                                   19,907
# Social transfers in kind (STiK): education                     2,393
# Social transfers in kind (STiK): health                        4,915
# Social transfers in kind (STiK): other                         3,348
#
#                                            Northwest Territories 1.2  \
# Categories
# Year Quartile                                                Q3 2020
# Household disposable income                                   19,900
# Social transfers in kind (STiK): education                     2,489
# Social transfers in kind (STiK): health                        5,129
# Social transfers in kind (STiK): other                         3,435
#
#                                            Northwest Territories 1.3  \
# Categories
# Year Quartile                                                Q4 2020
# Household disposable income                                   19,820
# Social transfers in kind (STiK): education                     2,570
# Social transfers in kind (STiK): health                        5,265
# Social transfers in kind (STiK): other                         3,609
#
#                                            Northwest Territories 1.4  \
# Categories
# Year Quartile                                                Q1 2021
# Household disposable income                                   18,951
# Social transfers in kind (STiK): education                     2,693
# Social transfers in kind (STiK): health                        5,646
# Social transfers in kind (STiK): other                         3,657
#
#                                            Northwest Territories 1.5  \
# Categories
# Year Quartile                                                Q2 2021
# Household disposable income                                   19,898
# Social transfers in kind (STiK): education                     2,607
# Social transfers in kind (STiK): health                        5,404
# Social transfers in kind (STiK): other                         3,429
#
#                                            Northwest Territories 1.6  \
# Categories
# Year Quartile                                                Q3 2021
# Household disposable income                                   21,080
# Social transfers in kind (STiK): education                     2,675
# Social transfers in kind (STiK): health                        5,597
# Social transfers in kind (STiK): other                         3,555
#
#                                            Northwest Territories 1.7  \
# Categories
# Year Quartile                                                Q4 2021
# Household disposable income                                   20,752
# Social transfers in kind (STiK): education                     2,735
# Social transfers in kind (STiK): health                        5,679
# Social transfers in kind (STiK): other                         3,659
#
#                                            Northwest Territories 1.8  \
# Categories
# Year Quartile                                                Q1 2022
# Household disposable income                                   23,618
# Social transfers in kind (STiK): education                     2,849
# Social transfers in kind (STiK): health                        6,148
# Social transfers in kind (STiK): other                         3,731
#
#                                            Northwest Territories 1.9  \
# Categories
# Year Quartile                                                Q2 2022
# Household disposable income                                   23,851
# Social transfers in kind (STiK): education                     2,737
# Social transfers in kind (STiK): health                        5,679
# Social transfers in kind (STiK): other                         3,643
#
#                                            Northwest Territories 1.10
# Categories
# Year Quartile                                                 Q3 2022
# Household disposable income                                    25,601
# Social transfers in kind (STiK): education                      2,813
# Social transfers in kind (STiK): health                         6,017
# Social transfers in kind (STiK): other                          3,767

# %%
#Calculate the yearly values for every category
NT_year = NT_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
NT_year = NT_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
NT_year = NT_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = NT_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = NT_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = NT_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
NT_peryear = pd.DataFrame({'Northwest Territories 2020': sum_col1, 'Northwest Territories 2021': sum_col2, 'Northwest Territories 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
NT_peryear['Total'] = NT_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
NT_peryear = NT_peryear.applymap(format_currency)

# Display the resulting dataframe
NT_peryear
# Out:
#                                                    Northwest Territories 2020  \
# Categories
# Household disposable income                                        $77,094.00
# Social transfers in kind (STiK): education                         $10,062.00
# Social transfers in kind (STiK): health                            $20,429.00
# Social transfers in kind (STiK): other                             $14,080.00
# Adjusted household disposable income                              $121,665.00
# Household final consumption expenditure (HFCE)                     $63,397.00
# Food and non-alcoholic beverages                                    $7,919.00
# Alcoholic beverages and tobacco                                     $3,709.00
# Clothing and footwear                                               $2,715.00
# Housing, water, electricity, gas and other fuels                   $20,514.00
# Furnishings, household equipment and other good...                  $3,329.00
# Health                                                              $1,213.00
# Transport                                                           $6,684.00
# Communications                                                      $1,580.00
# Recreation and culture                                              $5,314.00
# Education                                                             $738.00
# Food, beverage and accommodation services                           $3,759.00
# Insurance and financial services                                    $3,314.00
# Miscellaneous goods and services                                    $2,606.00
# Social transfers in kind (STiK)                                    $44,571.00
# Social transfers in kind (STiK): education                         $10,062.00
# Social transfers in kind (STiK): health                            $20,429.00
# Social transfers in kind (STiK): other                             $14,080.00
# Household actual final consumption                                $107,968.00
# Change in pension entitlements                                      $2,010.00
# Household net saving                                               $15,706.00
#
#                                                    Northwest Territories 2021  \
# Categories
# Household disposable income                                        $80,681.00
# Social transfers in kind (STiK): education                         $10,710.00
# Social transfers in kind (STiK): health                            $22,326.00
# Social transfers in kind (STiK): other                             $14,300.00
# Adjusted household disposable income                              $128,016.00
# Household final consumption expenditure (HFCE)                     $67,306.00
# Food and non-alcoholic beverages                                    $7,926.00
# Alcoholic beverages and tobacco                                     $3,708.00
# Clothing and footwear                                               $3,138.00
# Housing, water, electricity, gas and other fuels                   $21,153.00
# Furnishings, household equipment and other good...                  $3,605.00
# Health                                                              $1,326.00
# Transport                                                           $7,556.00
# Communications                                                      $1,579.00
# Recreation and culture                                              $5,816.00
# Education                                                             $748.00
# Food, beverage and accommodation services                           $4,379.00
# Insurance and financial services                                    $3,544.00
# Miscellaneous goods and services                                    $2,826.00
# Social transfers in kind (STiK)                                    $47,335.00
# Social transfers in kind (STiK): education                         $10,710.00
# Social transfers in kind (STiK): health                            $22,326.00
# Social transfers in kind (STiK): other                             $14,300.00
# Household actual final consumption                                $114,641.00
# Change in pension entitlements                                      $1,533.00
# Household net saving                                               $14,907.00
#
#                                                    Northwest Territories 2022  \
# Categories
# Household disposable income                                        $73,070.00
# Social transfers in kind (STiK): education                          $8,399.00
# Social transfers in kind (STiK): health                            $17,844.00
# Social transfers in kind (STiK): other                             $11,141.00
# Adjusted household disposable income                              $110,454.00
# Household final consumption expenditure (HFCE)                     $53,428.00
# Food and non-alcoholic beverages                                    $6,015.00
# Alcoholic beverages and tobacco                                     $2,663.00
# Clothing and footwear                                               $2,444.00
# Housing, water, electricity, gas and other fuels                   $16,654.00
# Furnishings, household equipment and other good...                  $2,661.00
# Health                                                              $1,054.00
# Transport                                                           $6,538.00
# Communications                                                      $1,172.00
# Recreation and culture                                              $4,518.00
# Education                                                             $575.00
# Food, beverage and accommodation services                           $4,243.00
# Insurance and financial services                                    $2,668.00
# Miscellaneous goods and services                                    $2,219.00
# Social transfers in kind (STiK)                                    $37,384.00
# Social transfers in kind (STiK): education                          $8,399.00
# Social transfers in kind (STiK): health                            $17,844.00
# Social transfers in kind (STiK): other                             $11,141.00
# Household actual final consumption                                 $90,812.00
# Change in pension entitlements                                        $907.00
# Household net saving                                               $20,547.00
#
#                                                           Total
# Categories
# Household disposable income                         $230,845.00
# Social transfers in kind (STiK): education           $29,171.00
# Social transfers in kind (STiK): health              $60,599.00
# Social transfers in kind (STiK): other               $39,521.00
# Adjusted household disposable income                $360,135.00
# Household final consumption expenditure (HFCE)      $184,131.00
# Food and non-alcoholic beverages                     $21,860.00
# Alcoholic beverages and tobacco                      $10,080.00
# Clothing and footwear                                 $8,297.00
# Housing, water, electricity, gas and other fuels     $58,321.00
# Furnishings, household equipment and other good...    $9,595.00
# Health                                                $3,593.00
# Transport                                            $20,778.00
# Communications                                        $4,331.00
# Recreation and culture                               $15,648.00
# Education                                             $2,061.00
# Food, beverage and accommodation services            $12,381.00
# Insurance and financial services                      $9,526.00
# Miscellaneous goods and services                      $7,651.00
# Social transfers in kind (STiK)                     $129,290.00
# Social transfers in kind (STiK): education           $29,171.00
# Social transfers in kind (STiK): health              $60,599.00
# Social transfers in kind (STiK): other               $39,521.00
# Household actual final consumption                  $313,421.00
# Change in pension entitlements                        $4,450.00
# Household net saving                                 $51,160.00

# %% [markdown]
# NUNAVUT

# %%
NU_data = data_df.loc[:, ['Nunavut 1', 
           'Nunavut 1.1', 
           'Nunavut 1.2', 
           'Nunavut 1.3', 
           'Nunavut 1.4', 
           'Nunavut 1.5', 
           'Nunavut 1.6', 
           'Nunavut 1.7', 
           'Nunavut 1.8', 
           'Nunavut 1.9', 
           'Nunavut 1.10']]


NU_data.head()
# Out:
#                                            Nunavut 1 Nunavut 1.1 Nunavut 1.2  \
# Categories
# Year Quartile                                Q1 2020     Q2 2020     Q3 2020
# Household disposable income                   15,675      19,015      17,948
# Social transfers in kind (STiK): education     3,367       2,991       3,119
# Social transfers in kind (STiK): health        7,949       7,512       7,774
# Social transfers in kind (STiK): other         4,942       4,430       4,548
#
#                                            Nunavut 1.3 Nunavut 1.4  \
# Categories
# Year Quartile                                  Q4 2020     Q1 2021
# Household disposable income                     17,334      16,673
# Social transfers in kind (STiK): education       3,198       3,181
# Social transfers in kind (STiK): health          7,920       7,706
# Social transfers in kind (STiK): other           4,743       4,640
#
#                                            Nunavut 1.5 Nunavut 1.6  \
# Categories
# Year Quartile                                  Q2 2021     Q3 2021
# Household disposable income                     16,826      17,787
# Social transfers in kind (STiK): education       3,092       3,190
# Social transfers in kind (STiK): health          7,289       7,603
# Social transfers in kind (STiK): other           4,328       4,508
#
#                                            Nunavut 1.7 Nunavut 1.8  \
# Categories
# Year Quartile                                  Q4 2021     Q1 2022
# Household disposable income                     16,755      25,814
# Social transfers in kind (STiK): education       3,177       3,272
# Social transfers in kind (STiK): health          7,519       9,057
# Social transfers in kind (STiK): other           4,521       4,594
#
#                                            Nunavut 1.9 Nunavut 1.10
# Categories
# Year Quartile                                  Q2 2022      Q3 2022
# Household disposable income                     26,575       29,117
# Social transfers in kind (STiK): education       3,049        3,221
# Social transfers in kind (STiK): health          8,169        8,908
# Social transfers in kind (STiK): other           5,487        5,801

# %%
#Calculate the yearly values for every category
NU_year = NU_data.drop(["Year Quartile"])

# Replace commas with empty strings in the columns to be summed
NU_year = NU_year.replace(',', '', regex=True)

# Convert values in DataFrame to numeric: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html
NU_year = NU_year.apply(pd.to_numeric, errors='coerce', downcast="integer")

# Sum the values for each row in the specified columns
sum_col1 = NU_year.iloc[:, 0:4].sum(axis=1)
sum_col2 = NU_year.iloc[:, 4:8].sum(axis=1)
sum_col3 = NU_year.iloc[:, 8:11].sum(axis=1)

# Create a new dataframe with the summed values
NU_peryear = pd.DataFrame({'Nunavut 2020': sum_col1, 'Nunavut 2021': sum_col2, 'Nunavut 2022': sum_col3})

# Add a new column to the dataframe with the total sum of each row
NU_peryear['Total'] = NU_peryear.sum(axis=1)

# Format the numbers as currency: https://stackabuse.com/format-number-as-currency-string-in-python/
def format_currency(num):
    return "${:,.2f}".format(num)

# Apply the function to the dataframe
NU_peryear = NU_peryear.applymap(format_currency)

# Display the resulting dataframe
NU_peryear
# Out:
#                                                    Nunavut 2020 Nunavut 2021  \
# Categories
# Household disposable income                          $69,972.00   $68,041.00
# Social transfers in kind (STiK): education           $12,675.00   $12,640.00
# Social transfers in kind (STiK): health              $31,155.00   $30,117.00
# Social transfers in kind (STiK): other               $18,663.00   $17,997.00
# Adjusted household disposable income                $132,464.00  $128,793.00
# Household final consumption expenditure (HFCE)       $47,451.00   $46,436.00
# Food and non-alcoholic beverages                      $7,483.00    $6,939.00
# Alcoholic beverages and tobacco                       $2,545.00    $2,340.00
# Clothing and footwear                                 $3,414.00    $3,665.00
# Housing, water, electricity, gas and other fuels     $17,398.00   $16,613.00
# Furnishings, household equipment and other good...    $3,082.00    $3,115.00
# Health                                                  $945.00      $954.00
# Transport                                             $2,619.00    $2,769.00
# Communications                                        $1,086.00    $1,005.00
# Recreation and culture                                $3,172.00    $3,240.00
# Education                                               $542.00      $508.00
# Food, beverage and accommodation services             $1,709.00    $1,850.00
# Insurance and financial services                      $1,308.00    $1,292.00
# Miscellaneous goods and services                      $2,152.00    $2,147.00
# Social transfers in kind (STiK)                      $62,492.00   $60,752.00
# Social transfers in kind (STiK): education           $12,675.00   $12,640.00
# Social transfers in kind (STiK): health              $31,155.00   $30,117.00
# Social transfers in kind (STiK): other               $18,663.00   $17,997.00
# Household actual final consumption                  $109,943.00  $107,188.00
# Change in pension entitlements                        $5,897.00    $6,154.00
# Household net saving                                 $28,418.00   $27,758.00
#
#                                                    Nunavut 2022        Total
# Categories
# Household disposable income                          $81,506.00  $219,519.00
# Social transfers in kind (STiK): education            $9,542.00   $34,857.00
# Social transfers in kind (STiK): health              $26,134.00   $87,406.00
# Social transfers in kind (STiK): other               $15,882.00   $52,542.00
# Adjusted household disposable income                $133,065.00  $394,322.00
# Household final consumption expenditure (HFCE)       $38,029.00  $131,916.00
# Food and non-alcoholic beverages                      $5,449.00   $19,871.00
# Alcoholic beverages and tobacco                       $1,735.00    $6,620.00
# Clothing and footwear                                 $2,952.00   $10,031.00
# Housing, water, electricity, gas and other fuels     $13,458.00   $47,469.00
# Furnishings, household equipment and other good...    $2,374.00    $8,571.00
# Health                                                  $785.00    $2,684.00
# Transport                                             $2,878.00    $8,266.00
# Communications                                          $769.00    $2,860.00
# Recreation and culture                                $2,541.00    $8,953.00
# Education                                               $403.00    $1,453.00
# Food, beverage and accommodation services             $1,939.00    $5,498.00
# Insurance and financial services                      $1,012.00    $3,612.00
# Miscellaneous goods and services                      $1,733.00    $6,032.00
# Social transfers in kind (STiK)                      $51,559.00  $174,803.00
# Social transfers in kind (STiK): education            $9,542.00   $34,857.00
# Social transfers in kind (STiK): health              $26,134.00   $87,406.00
# Social transfers in kind (STiK): other               $15,882.00   $52,542.00
# Household actual final consumption                   $89,588.00  $306,719.00
# Change in pension entitlements                        $4,524.00   $16,575.00
# Household net saving                                 $48,000.00  $104,176.00
