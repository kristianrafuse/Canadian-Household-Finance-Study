# %% [markdown]
# ## Analysis
#
# ----------------------------------------------------------------
#
# Through the analysis of data provided by Statistics Canada, we can gain insights into the spending habits of Canadian households over the past decade, from 2012 to 2022. This initial analysis was exploratory in nature, aiming to provide insight into Canadian spending. Simply put: “What are Canadians spending their money on?”. Looking at this data can provide Canadians with useful insights into how they spend their money and how their spending habits compare to those of other households in Canada. By understanding the share of expenditures by category, for example, Canadians can get a sense of where their money is going and potentially identify areas where they can cut back on spending or find more cost-effective solutions.
#
# For example, if a household spends a large proportion of their income on housing, they may want to consider downsizing or finding more affordable housing options. Similarly, if a household spends a significant amount on transportation, they may want to consider alternatives to driving, such as public transportation or carpooling.
#
# Furthermore, understanding the trends in household net saving can also be useful in helping Canadians make financial decisions. A higher net saving rate may indicate that a household is living within its means and is better able to weather financial emergencies. On the other hand, a lower net saving rate may indicate that a household is living beyond its means and may be at risk of financial instability.
#
# Overall, by examining this data and comparing it to their own spending and income habits, Canadians can make more informed decisions about their finances and potentially identify areas where they can make changes to improve their financial health.
# As we will see below, the data shows that Canadian households spend a significant proportion of their income on housing, transportation, food, and recreation. These categories consistently make up the largest shares of household expenditures over the years. Furthermore, the data shows that household net saving rates have increased in recent years, which may suggest that Canadians are becoming more cautious with their spending and are saving more of their income.
#
# However, the increased savings, whether from caution or government stimulus during the pandemic, should be tempered by our observations of Canadian debt. In addition to expenditures and savings, we also observed increasing household debt levels. This data indicates that household debt levels have been on the rise, particularly in the form of mortgage debt and credit card debt. This may indicate that some Canadians are taking on more debt to maintain their standard of living or to purchase homes in increasingly expensive markets.
#
# Overall, we can see that there have been some notable recent changes in some categories from 2019 to 2022. Depsite behing historically quite stable. Housing, water, electricity, gas, and other fuels have increased as a percentage of income, while transport, food and non-alcoholic beverages, and recreation and culture have all decreased. Insurance and financial services, miscellaneous goods and services, and health have all increased slightly, while food, beverage and accommodation services, clothing and footwear, and furnishings and household equipment have all decreased. Additionally, household net saving has increased significantly from 2.0% in 2019 to 5.9% in 2022.
#
# Our initial analysis suggests that Canadians are facing challenges in balancing their spending and saving habits, particularly in the face of rising housing and living costs. It highlights the importance of making informed decisions about spending, debt, and savings.
#
# We saw that there has been a consistent increase in the percentage of income that Canadians spend on housing-related expenses. Though the percent of income spent on Housing, Water, Electricity, Gas and Other Fuels has remained similar from 2012 to 2022, Furnishings, Household Equipment, and Routine Household Maintenance has increased. This suggests that Canadians are spending more on maintaining and improving their homes, potentially driven by rising housing costs and a desire for more comfortable living spaces.
#
# Another significant trend we observed is the decrease in the percentage of income that Canadians spend on transportation. Transport expenditures, including the purchase of vehicles and related expenses such as fuel and maintenance, have declined from 2012 to 2022. This could be due to a number of factors, including the rise of remote work and the increased availability of public transportation in some areas.
#
# Food and non-alcoholic beverages also make up a significant portion of Canadian household expenditures, accounting for 13.5% of income in 2012 and 12.5% in 2022. While this percentage has decreased slightly over the past decade, it remains a major expense for Canadian households. Interestingly, despite the increase in housing and household-related expenditures, the percentage of income that Canadians save has also risen from 2.6% in 2012 to 6.8% in 2022. This suggests that Canadians are managing to balance their spending with an increased focus on savings and financial planning. Recent trends from our analysis of quarterly expenses, however, suggests that costs are steadily increasing in tandem with a decrease in overall savings, especially from Q2 2020 to Q2 2022.
#
# However, it is important to note that overall Canadian debt levels, particularly mortgage and credit card debt, have also increased during this time period. This highlights the need for Canadians to carefully manage their spending and debt levels, particularly in the areas of housing and credit card usage. Lastly, the data on Canadian household expenditures from 2012 to 2022 reveals several important trends in Canadian spending habits. While there has been an increase in the percentage of income spent on housing-related expenses, Canadians have also managed to increase their savings rate. However, the rise in overall debt levels, particularly in mortgage and credit card debt, suggests the need for Canadians to carefully manage their finances and debt levels.
#
# ----------------------------------------------------------------
#
#
# Sources:
#
# Statistics Canada. Table 36-10-0588-01
#
# Distributions of household economic accounts, income, consumption and saving, Canada, provinces and territories, annual (x 1,000,000)
#
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3610058801
#
# ----------------------------------------------------------------
#
# Statistics Canada. Table 36-10-0124-01
#
# Detailed household final consumption expenditure, Canada, quarterly (x 1,000,000)
#
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3610012401
#
#
# ----------------------------------------------------------------
#
# Statistics Canada. Table 36-10-0639-01
#
# Credit liabilities of households (x 1,000,000)
#
# https://www150.statcan.gc.ca/t1/tbl1/en/tv.action?pid=3610063901

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#csv file path
quarterly = pd.read_csv("../data/quarterly distributions.csv")
quarterly = quarterly.set_index('Income, consumption and savings')

# %%
#read_csv, initial data organizing, tidying.
annually = pd.read_csv("../data/annual distributions.csv")
annually = pd.DataFrame(annually)
annually = annually.set_index('Income, consumption and savings')
annually = annually.rename_axis(' ')

# %%
#transpose csv to set-up for creating line graphs
annually_transposed = annually.transpose()

# %%
#set the datatype of csv and remove special characters
annually_transposed = annually_transposed.replace(',', '', regex=True).astype(float)
annually_transposed
# Out:
#       Household disposable income  Compensation of employees  \
# 2012                      42734.0                    39330.0
# 2013                      44016.0                    40332.0
# 2014                      44949.0                    41400.0
# 2015                      46528.0                    42199.0
# 2016                      46162.0                    41736.0
# 2017                      47725.0                    42795.0
# 2018                      48769.0                    44683.0
# 2019                      50322.0                    45929.0
# 2020                      54118.0                    45087.0
# 2021                      55565.0                    48642.0
# 2022                      56747.0                    51719.0
#
#       Net mixed income  Property income received  Less: property income paid  \
# 2012            6954.0                    7270.0                      2373.0
# ...

# %%
#creating columns as a Percent of Income
annually_transposed['% Clothing and Footwear'] = 100* (annually_transposed['Clothing and footwear']/annually_transposed['Adjusted household disposable income'])

# %%
#charting as a percent of income over 10 years
annually_transposed['% Clothing and Footwear'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Clothing and Footwear')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/Percent of Income Spent on Clothing and Footwear")

# %%
annually_transposed['% Food and Non-alcoholic Beverages'] = 100* (annually_transposed['Food and non-alcoholic beverages']/annually_transposed['Adjusted household disposable income'])

# %%
annually_transposed['% Food and Non-alcoholic Beverages'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Food')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/Percent of Income on Food")

# %%
annually_transposed['% Housing, Water, Electricity, Gas and Other Fuels'] = 100* (annually_transposed['Housing, water, electricity, gas and other fuels']/annually_transposed['Adjusted household disposable income'])
annually_transposed['% Housing, Water, Electricity, Gas and Other Fuels'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Housing')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/Percent of Income on Housing")

# %%
annually_transposed['% Household final consumption expenditure'] = 100* (annually_transposed['Household final consumption expenditure (HFCE)']/annually_transposed['Adjusted household disposable income'])
annually_transposed['% Household final consumption expenditure'].plot(linewidth=6, kind='line')

plt.title('Percent of Total Consumption vs. Income')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/Percent of Total Consumption")

# %%
annually_transposed['% Household Net Saving'] = 100* (annually_transposed['Household net saving']/annually_transposed['Adjusted household disposable income'])
annually_transposed['% Household Net Saving'].plot(linewidth=6, kind='line')
plt.title('Household Net Saving as Percent of Income')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/Household Net Saving as Percent of Income")

# %%
annually_transposed['% Alcoholic Beverages and Tobacco'] = 100* (annually_transposed['Alcoholic beverages and tobacco']/annually_transposed['Adjusted household disposable income'])
annually_transposed['% Alcoholic Beverages and Tobacco'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Alcoholic Beverages and Tobacco')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Income on Alcoholic Beverages and Tobacco")

# %%
annually_transposed['% Furnishings, Household Equipment'] = 100* (annually_transposed['Furnishings, household equipment and other goods and services related to the dwelling and property'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Furnishings, Household Equipment'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Furnishings, Household Equipment')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Income Furnishings, Household Equipment")

# %%
annually_transposed['% Recreation and Culture'] = 100* (annually_transposed['Recreation and culture'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Recreation and Culture'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent Recreation and culture')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Recreation and culture")

# %%
annually_transposed['% Insurance and Financial Services'] = 100* (annually_transposed['Insurance and financial services'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Insurance and Financial Services'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Insurance and Financial Services')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Insurance and financial services")

# %%
annually_transposed['% Miscellaneous Goods and Services'] = 100* (annually_transposed['Miscellaneous goods and services'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Miscellaneous Goods and Services'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Miscellaneous Goods and Services')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Miscellaneous goods and services")

# %%
annually_transposed['% Health'] = 100* (annually_transposed['Health'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Health'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Health')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Health")

# %%
annually_transposed['% Transport'] = 100* (annually_transposed['Transport'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Transport'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Transport')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Transport")

# %%
annually_transposed['% Food, Beverage and Accommodation Services'] = 100* (annually_transposed['Food, beverage and accommodation services'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Food, Beverage and Accommodation Services'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Food, Beverage and Accommodation Services')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Food, beverage and accommodation services")

# %%
annually_transposed['% Education'] = 100* (annually_transposed['Education'] / annually_transposed['Adjusted household disposable income'])
annually_transposed['% Education'].plot(linewidth=6, kind='line')
plt.title('Percent of Income Spent on Education')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig("../graphs/%Transport")

# %%
#merging similar categories
annually_transposed.plot(linewidth=6, y=['% Education', '% Transport', '% Health'], kind='line')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig('../graphs/%Education%Transport%Health')

# %%
annually_transposed.plot(linewidth=6, y=['% Housing, Water, Electricity, Gas and Other Fuels', '% Furnishings, Household Equipment', '% Insurance and Financial Services'], kind='line')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig('../graphs/HousingHouseholdInsurance')

# %%
annually_transposed.plot.line(linewidth=6, y=['% Food, Beverage and Accommodation Services', '% Food and Non-alcoholic Beverages', '% Alcoholic Beverages and Tobacco'])
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig('../graphs/FoodAlcoholService')

# %%
annually_transposed.plot(linewidth=6,y=['% Clothing and Footwear', '% Recreation and Culture', '% Miscellaneous Goods and Services'], kind='line')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig('../graphs/ClothingRecMisc')

# %%
#creating one chart to rule them all.

annually_transposed.plot(xticks=range(11), linewidth=8, figsize=(15, 15), y=[
                                        '% Housing, Water, Electricity, Gas and Other Fuels'
                                        ,'% Transport'
                                        ,'% Food and Non-alcoholic Beverages'
                                        ,'% Recreation and Culture'
                                        ,'% Insurance and Financial Services'
                                        ,'% Food, Beverage and Accommodation Services'
                                        ,'% Clothing and Footwear'
                                        ,'% Furnishings, Household Equipment'
                                        ,'% Miscellaneous Goods and Services'
                                        ,'% Health'
                                        ,'% Household Net Saving'
                                        ,'% Alcoholic Beverages and Tobacco'
                                        ,'% Education',],kind='line')
plt.legend(loc='upper left')
plt.title('Canadian Spending as a Percentage of Income')
plt.xlabel('Year')
plt.ylabel('Percent of Income')
plt.savefig('../graphs/Canadian Spending as a Percentage of Income')

# %%
annually_transposed.columns
# Out:
# Index(['Household disposable income', 'Compensation of employees',
#        'Net mixed income', 'Property income received',
#        'Less: property income paid', 'Current transfers received',
#        'Less: current transfers paid', 'Social transfers in kind (STiK)',
#        'Social transfers in kind (STiK): education',
#        'Social transfers in kind (STiK): health',
#        'Social transfers in kind (STiK): other',
#        'Adjusted household disposable income',
#        'Household final consumption expenditure (HFCE)',
#        'Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
#        'Clothing and footwear',
#        'Housing, water, electricity, gas and other fuels',
#        'Furnishings, household equipment and other goods and services related to the dwelling and property',
#        'Health', 'Transport', 'Communications', 'Recreation and culture',
#        'Education', 'Food, beverage and accommodation services',
# ...

# %%
#visualizing total spending for the year 2019 
#selecting the relevant columsn from the dataset

df_2019_select = annually_transposed.loc['2019':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

#renaming for visualizing below - it was too long

df_2019_select = df_2019_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})

#transposing the df to setup for pie chart. 

df_2019_select = df_2019_select.T

df_2019_select.plot.pie(y=0, figsize=(15, 15), legend=False, autopct='%1.1f%%', title='Canadian Spending in 2019')

plt.xlabel('')
plt.ylabel('')
plt.savefig('../graphs/Spending2019')
plt.show()

# %%
#repeat

df_2020_select = annually_transposed.loc['2020':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

df_2020_select = df_2020_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})

df_2020_select = df_2020_select.T

df_2020_select.plot.pie(y=0, figsize=(15, 15), legend=False, autopct='%1.1f%%', title='Canadian Spending in 2020')

plt.xlabel('')
plt.ylabel('')
plt.savefig('../graphs/Spending2020')
plt.show()

# %%
df_2021_select = annually_transposed.loc['2021':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

df_2021_select = df_2021_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})


df_2021_select = df_2021_select.T

df_2021_select.plot.pie(y=0, figsize=(15, 15), legend=False, autopct='%1.1f%%', title='Canadian Spending in 2021')
plt.xlabel('')
plt.ylabel('')
plt.savefig('../graphs/Spending2021')
plt.show()

# %%
df_2022_select = annually_transposed.loc['2022':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

df_2022_select = df_2022_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})


df_2022_select = df_2022_select.T

df_2022_select.plot.pie(y=0, figsize=(15, 15), legend=False, autopct='%1.1f%%', title='Canadian Spending in 2022')
plt.xlabel('')
plt.ylabel('')
plt.savefig('../graphs/Spending2022')
plt.show()

# %%
df_2012_select = annually_transposed.loc['2012':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

df_2012_select = df_2012_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})


df_2012_select = df_2012_select.T

df_2012_select.plot.pie(y=0, figsize=(15, 15), legend=False, autopct='%1.1f%%', title='Canadian Spending in 2012')
plt.xlabel('')
plt.ylabel('')
plt.savefig('../graphs/Spending2012')
plt.show()

# %%
#just having a look
annually_transposed
# Out:
#       Household disposable income  Compensation of employees  \
# 2012                      42734.0                    39330.0
# 2013                      44016.0                    40332.0
# 2014                      44949.0                    41400.0
# 2015                      46528.0                    42199.0
# 2016                      46162.0                    41736.0
# 2017                      47725.0                    42795.0
# 2018                      48769.0                    44683.0
# 2019                      50322.0                    45929.0
# 2020                      54118.0                    45087.0
# 2021                      55565.0                    48642.0
# 2022                      56747.0                    51719.0
#
#       Net mixed income  Property income received  Less: property income paid  \
# 2012            6954.0                    7270.0                      2373.0
# ...

# %%
#creating a new row that is the average.
new_row = pd.DataFrame(annually_transposed.mean(axis=0), columns=['Average']).transpose()
average_df = pd.concat([annually_transposed, new_row])

# %%
#checkin out my new row. Nice.
average_df
# Out:
#          Household disposable income  Compensation of employees  \
# 2012                    42734.000000               39330.000000
# 2013                    44016.000000               40332.000000
# 2014                    44949.000000               41400.000000
# 2015                    46528.000000               42199.000000
# 2016                    46162.000000               41736.000000
# 2017                    47725.000000               42795.000000
# 2018                    48769.000000               44683.000000
# 2019                    50322.000000               45929.000000
# 2020                    54118.000000               45087.000000
# 2021                    55565.000000               48642.000000
# 2022                    56747.000000               51719.000000
# Average                 48875.909091               43986.545455
#
#          Net mixed income  Property income received  \
# 2012          6954.000000               7270.000000
# ...

# %%
df_Average_select = average_df.loc['Average':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

df_Average_select = df_Average_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})

df_Average_select = df_Average_select.T

df_Average_select.plot.pie(y=0, figsize=(15, 15), legend=False, autopct='%1.1f%%', title='Average Spending For Last 10 Years')
plt.xlabel('')
plt.ylabel('')
plt.savefig('../graphs/SpendingAverage')
plt.show()

# %%
#setup the quarterly data for analysis
quarterly = quarterly.replace(',', '', regex=True).astype(float)
#get average month from last quater of 2022
quarterly['Monthly'] = quarterly['Q4 2022']/3
#transpose to setup for chart
quarterly_T = quarterly.T

# %%
# Slice the DataFrame to include only the columns you want
quarterly_T_select = quarterly_T.loc['Monthly':, ['Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings, household equipment and other goods and services related to the dwelling and property',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services', 'Household net saving']]

# Rename the column you want to change
quarterly_T_select = quarterly_T_select.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})

# Transpose the DataFrame so that the columns become rows
quarterly_T_select = quarterly_T_select.T

# Calculate the total of each row and create a new column with the total
quarterly_T_select['total1'] = quarterly_T_select.sum(axis=1)

# Create the pie chart with both percentage and actual values
fig, ax = plt.subplots(figsize=(20, 20))
quarterly_T_select.plot.pie(fontsize=12, y='total1', ax=ax, legend=False, autopct=lambda x: '{:.1f}% (${:.0f})'.format(x, x * quarterly_T_select['total1'].sum() / 100))
plt.title('Average Canadian Monthly Spending, Q4 2022')

ax.set_xlabel('')
ax.set_ylabel('')
plt.savefig('../graphs/Average Canadian Monthly Spending, Q4 2022')
plt.show()

# %%
#reorienting, removing average for plotting line
quarterly2 = quarterly.T
quarterly2 = quarterly2.rename(columns={'Furnishings, household equipment and other goods and services related to the dwelling and property': 'Furnishings and Household equipment'})
quarterly2 = quarterly2.drop('Monthly')
quarterly2
# Out:
# Income, consumption and savings  Household disposable income  \
# Q1 2020                                              12182.0
# Q2 2020                                              13880.0
# Q3 2020                                              14223.0
# Q4 2020                                              13847.0
# Q1 2021                                              13189.0
# Q2 2021                                              13604.0
# Q3 2021                                              14707.0
# Q4 2021                                              14070.0
# Q1 2022                                              13279.0
# Q2 2022                                              13673.0
# Q3 2022                                              14794.0
# Q4 2022                                              14985.0
#
# Income, consumption and savings  Compensation of employees  Net mixed income  \
# Q1 2020                                            11300.0            1915.0
# ...

# %%
quarterly2.plot(linewidth=8, figsize=(20, 20), xticks=range(12), y=['Household net saving', 'Food and non-alcoholic beverages', 'Alcoholic beverages and tobacco',
       'Clothing and footwear',
       'Housing, water, electricity, gas and other fuels',
       'Furnishings and Household equipment',
       'Health', 'Transport', 'Communications', 'Recreation and culture',
       'Education', 'Food, beverage and accommodation services',
       'Insurance and financial services', 'Miscellaneous goods and services'],kind='line')
plt.legend(loc='upper left')
plt.title('Canadian Spending Per Quarter 2020-2022')
plt.xlabel('Quarter')
plt.ylabel('Dollars')
plt.savefig('../graphs/Canadian Spending Per Quarter')

# %%
#reading in new csv
debt = pd.read_csv("../data/creditliabilities.csv")

# %%
#removing every column that had "symbol" as the header and no data

symbol_columns = [col for col in debt.columns if 'Symbol' in col]

debt.drop(symbol_columns, axis=1, inplace=True)

# %%
#selecting the credit card debt to analyze
cc_debt = pd.DataFrame(debt.iloc[4]).transpose()

# %%
#setting the index so that i'm running commands below on just the data, now row headers.
cc_debt = cc_debt.set_index("Credit liabilities of households 1 2 3")

# %%
cc_debt = cc_debt.replace(',', '', regex=True).astype(float)

cc_debt = cc_debt.T

# %%
cc_debt.plot(linewidth=12, figsize=(20, 20), color='darkred')

plt.legend(loc='upper left', labels=['Household Credit Card Debt'])
plt.title('Total Canadian Household Credit Card Debt', fontsize=16)
plt.xlabel('January 2017 to Decemeber 2022')
plt.ylabel('Total Household Credit Card Debt x 1 000 000')
plt.savefig('../graphs/Total Canadian Credit Card Debt')

# %%
debt
# Out:
#                Credit liabilities of households 1 2 3     17-Jan     17-Feb  \
# 0                                  Non-mortgage loans    667,394    670,454
# 1                                   Chartered banks 1    477,815    478,637
# 2                                  Personal loans 1 2     99,313     99,610
# 3                            Of which: Auto loans 1 2     76,929     77,288
# 4                                    Credit cards 1 2     81,040     81,261
# 5                               Lines of credit 1 2 4    246,554    246,848
# 6   Lines of credit, of which: excluding home equi...     70,991     71,068
# 7                            Other personal loans 1 2     20,026     20,217
# 8                         Unincorporated business 1 2     30,882     30,701
# 9                                         Non-banks 1    189,579    191,817
# 10                                     Government 1 5     27,065     27,201
# ...

# %%
#repeat
res_mortages = pd.DataFrame(debt.iloc[18]).transpose()
res_mortages = res_mortages.set_index("Credit liabilities of households 1 2 3")
res_mortages = res_mortages.replace(',', '', regex=True).astype(float)

#values were too large to display correct in the axis, so I made them all smaller
res_mortages.loc[res_mortages.index[0], :] /= 10

res_mortages = res_mortages.T
res_mortages.plot(linewidth=12, figsize=(20, 20), color='darkred')

plt.legend(loc='upper left', labels=['Residental Mortages'])
plt.title('Total Canadian Residential Mortage Debt', fontsize=16)
plt.xlabel('January 2017 to Decemeber 2022')
plt.ylabel('Total Residential Mortage Debt x $10 000 000')
plt.savefig('../graphs/Total Residential Mortage Debt')
