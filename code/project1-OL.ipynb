# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 
import scipy.stats as st
import pprint as pprint

# %% [markdown]
#             Disposable income by income quintile, including gap between top two and bottom two income quintiles

# %%
#read adn display the data(disposable income by income quintile, including gap between top two and bottom two income quintiles)

disposable_income_quintile=pd.read_csv("t001b-eng (2).csv")
disposable_income_quintile.head()
# Out:
#                                                                Table 1 – Share of disposable income by income quintile, including gap between top two and bottom two income quintiles
#                             Average (2010 to 2019)  2020  2021                                               2022
# NaN                        %                       %     %                                                      %
# Disposable income quintile NaN                     NaN   NaN                                                  NaN
# Lowest income quintile     6.3                     7.4   7.1                                                  7.1
# Second income quintile     12.6                    13.5  13.3                                                13.5

# %%
#clean the data 
disposable_income_quintile.dropna()
# Out:
#                                                                                        Table 1 – Share of disposable income by income quintile, including gap between top two and bottom two income quintiles
#                                                     Average (2010 to 2019)  2020  2021                                               2022
# NaN                                                %                       %     %                                                      %
# Lowest income quintile                             6.3                     7.4   7.1                                                  7.1
# Second income quintile                             12.6                    13.5  13.3                                                13.5
# Third income quintile                              17.2                    17.5  17.6                                                17.4
# ...

# %%
# Define the column widths and the header row
income_quintile = 10
Average_2010to2019 = 10
year_2020 = 10
year_2021 = 10
year_2022=10
highest_income=10
header = f"{'Disposable income quintile'.ljust(income_quintile)} | {'Average 2010 to 2019'.ljust(Average_2010to2019)} | {'2020'.ljust(year_2020)}    | {'2021'.ljust(year_2021)}     |  {'2022'.ljust(year_2022)}"

# Define the rows of data
row1 = f"{'Lowest income quintile'.ljust(income_quintile)}    | {str(6.3)+'%'.ljust(Average_2010to2019)}         | {str(7.4)+'%'.ljust(year_2020)} | {str(7.1)+'%'.ljust(year_2021)}  | {str(7.1)+'%'.ljust(year_2022)}"
row2 = f"{'Second income quintile'.ljust(income_quintile)}    | {str(12.6)+'%'.ljust(Average_2010to2019)}        | {str(13.5)+'%'.ljust(year_2020)}| {str(13.3)+'%'.ljust(year_2021)} | {str(13.5)+'%'.ljust(year_2022)}"
row3 = f"{'Third income quintile'.ljust(income_quintile)}     | {str(17.2)+'%'.ljust(Average_2010to2019)}        | {str(17.5)+'%'.ljust(year_2020)}| {str(17.6)+'%'.ljust(year_2021)} | {str(17.4)+'%'.ljust(year_2022)}"
row4 = f"{'Fourth income quintile'.ljust(income_quintile)}    | {str(23.3)+'%'.ljust(Average_2010to2019)}        | {str(23.6)+'%'.ljust(year_2020)}| {str(23)+'%'.ljust(year_2021)}   | {str(23)+'%'.ljust(year_2022)}"
row5 = f"{'Highest income quintile'.ljust(income_quintile)}   | {str(40.7)+'%'.ljust(Average_2010to2019)}        | {str(38.1)+'%'.ljust(year_2020)}| {str(39.1)+'%'.ljust(year_2021)} | {str(39)+'%'.ljust(year_2022)}"
# Print the table
print(header)
print("-" * len(header))
print(row1)
print(row2)
print(row3)
print(row4)
print (row5)
# Out:
# Disposable income quintile | Average 2010 to 2019 | 2020          | 2021           |  2022
# ------------------------------------------------------------------------------------------------
# Lowest income quintile    | 6.3%                  | 7.4%          | 7.1%           | 7.1%
# Second income quintile    | 12.6%                 | 13.5%         | 13.3%          | 13.5%
# Third income quintile     | 17.2%                 | 17.5%         | 17.6%          | 17.4%
# Fourth income quintile    | 23.3%                 | 23.6%         | 23%            | 23%
# Highest income quintile   | 40.7%                 | 38.1%         | 39.1%          | 39%

# %%
# Define the data
labels = ['Lowest', 'Second', 'Third', 'Fourth', 'Highest']
avg_2010_2019 = [6.3, 12.6, 17.2, 23.3, 40.7]
avg_2020 = [7.4, 13.5, 17.5, 23.6, 38.1]
avg_2021 = [7.1, 13.3, 17.6, 23.0, 39.1]
avg_2022 = [7.1, 13.5, 17.4, 23.0, 39.0]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

# Create the figure and axes
fig, ax = plt.subplots()

# Plot the data for each year
rects1 = ax.bar(x - 3*width/2, avg_2010_2019, width, label='Average 2010-2019')
rects2 = ax.bar(x - width/2, avg_2020, width, label='2020')
rects3 = ax.bar(x + width/2, avg_2021, width, label='2021')
rects4 = ax.bar(x + 3*width/2, avg_2022, width, label='2022')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Disposable income (%)')
ax.set_title('Disposable income by quintile and year')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Display the chart
plt.show()

# %% [markdown]
#               Disposable income by income quintile, average dollars per household, 2022 relative to 2021

# %%
#Read and display the data(Disposable income by income quintile, average dollars per household, 2022 relative to 2021)

disposable_income_dollars=pd.read_csv("t002b-eng.csv")
disposable_income_dollars.head()
# Out:
#                                                      Table 2 – Disposable income by income quintile, average dollars per household, 2022 relative to 2021
#                         2021    2022    2021 to 2022                                       2021 to 2022
# NaN                    dollars dollars dollars                                                        %
# All households         91975   93580   1605                                                         1.7
# Lowest income quintile 32569   33075   506                                                          1.6
# Second income quintile 61083   63055   1972                                                         3.2

# %%
#Clean the data 
disposable_income_dollars.dropna()
# Out:
#                                                       Table 2 – Disposable income by income quintile, average dollars per household, 2022 relative to 2021
#                          2021    2022    2021 to 2022                                       2021 to 2022
# NaN                     dollars dollars dollars                                                        %
# All households          91975   93580   1605                                                         1.7
# Lowest income quintile  32569   33075   506                                                          1.6
# Second income quintile  61083   63055   1972                                                         3.2
# Third income quintile   80788   81616   828                                                          1.0
# Fourth income quintile  105546  107662  2116                                                         2.0
# ...

# %%
# Define the column widths and the header row
income_quintile_dollars = 10
dollars_2021 = 10
dollars_2022 = 10
dollars2021to2022 = 10
porcentage_dollars = 10

header = f"{'Disposable income by income quintile'.ljust(income_quintile)}  /   {'2021'.ljust(dollars_2021)}   /   {'2022 '.ljust(dollars_2022)} /  {'2021 to 2022'.ljust(dollars2021to2022)}  /  {'percentage 2021 to 2022'.ljust(porcentage_dollars)}"

# Define the rows of data
row1 = f"{'Lowest income quintile'.ljust(income_quintile)}                  ${str(32569).ljust(dollars_2021)}      ${str(33075).ljust(dollars_2022)}      ${str(506).ljust(dollars2021to2022)}          {str(1.6).ljust(porcentage_dollars)+'%'}         "
row2 = f"{'Second income quintile'.ljust(income_quintile)}                  ${str(61083).ljust(dollars_2021)}      ${str(63055).ljust(dollars_2022)}      ${str(1972).ljust(dollars2021to2022)}          {str(3.2).ljust(porcentage_dollars)+'%'}         "
row3 = f"{'Third income quintile'.ljust(income_quintile)}                   ${str(80788).ljust(dollars_2021)}      ${str(81616).ljust(dollars_2022)}      ${str(828).ljust(dollars2021to2022)}          {str(1).ljust(porcentage_dollars)+'%'}        "
row4 = f"{'Fourth income quintile'.ljust(income_quintile)}                  ${str(105546).ljust(dollars_2021)}     ${str(107662).ljust(dollars_2021)}       ${str(2116).ljust(dollars_2021)}          {str(2).ljust(porcentage_dollars)+'%'}         "
row5 = f"{'Highest income quintile'.ljust(income_quintile)}                 ${str(179890).ljust(dollars_2021)}     ${str(182494).ljust(dollars_2021)}       ${str(2604).ljust(dollars_2021)}          {str(1.4).ljust(porcentage_dollars)+'%'}         "
# Print the table
print(header)
print("-" * len(header))
print(row1)
print(row2)
print(row3)
print(row4)
print(row5)
# Out:
# Disposable income by income quintile  /   2021         /   2022       /  2021 to 2022  /  percentage 2021 to 2022
# -----------------------------------------------------------------------------------------------------------------
# Lowest income quintile                  $32569           $33075           $506                 1.6       %
# Second income quintile                  $61083           $63055           $1972                3.2       %
# Third income quintile                   $80788           $81616           $828                 1         %
# Fourth income quintile                  $105546         $107662           $2116                2         %
# Highest income quintile                 $179890         $182494           $2604                1.4       %

# %%
# Define the rows of data
rows = [    ["Lowest income quintile", 32569, 33075, 506, 1.6],
    ["Second income quintile", 61083, 63055, 1972, 3.2],
    ["Third income quintile", 80788, 81616, 828, 1],
    ["Fourth income quintile", 105546, 107662, 2116, 2],
    ["Highest income quintile", 179890, 182494, 2604, 1.4]
]

# Define the column headers
header = ["Income Quintile", "2021", "2022", "2021 to 2022", "Percentage 2021 to 2022"]

# Create the table
fig, ax = plt.subplots()
ax.axis('off')
ax.axis('tight')
ax.table(cellText=rows, colLabels=header, loc='center')

plt.show()

# %%
# Define the data as lists
labels = ['Lowest', 'Second', 'Third', 'Fourth', 'Highest']
values_2021 = [32569, 61083, 80788, 105546, 179890]
values_2022 = [33075, 63055, 81616, 107662, 182494]

# Create the bar chart
fig, ax = plt.subplots()
ax.bar(labels, values_2021, label='2021')
ax.bar(labels, values_2022, bottom=values_2021, label='2022')
ax.set_xlabel('Income quintile')
ax.set_ylabel('Disposable income ($)')
ax.set_title('Disposable income by income quintile')
ax.legend()

# Display the chart
plt.show()

# %% [markdown]
#     Net worth by wealth quintile, average dollars per household, fourth quarter of 2022 relative to fourth quarter of 2021

# %%
#Read and diplsay the data (Net worth by wealth quintile, average dollars per household, fourth quarter of 2022 relative to fourth quarter of 2021)

net_worth_quintile=pd.read_csv("t003b-eng.csv")
net_worth_quintile.head()
# Out:
#                                                                                                                          Table 3 – Net worth by wealth quintile, average dollars per household, fourth quarter of 2022 relative to fourth quarter of 2021
#                                     Fourth quarter 2021  Fourth quarter 2022  Fourth quarter 2021 to fourth quarter 2022         Fourth quarter 2021 to fourth quarter 2022
# NaN                                dollars              dollars              dollars                                                                                      %
# All households                     1000667              936181               -64486                                                                                    -6.4
# Lowest and second wealth quintiles 72507                60679                -11828                                                                                   -16.3
# ...

# %%
#Clean the data 
net_worth_quintile.dropna()
# Out:
#                                                                                                                          Table 3 – Net worth by wealth quintile, average dollars per household, fourth quarter of 2022 relative to fourth quarter of 2021
#                                     Fourth quarter 2021  Fourth quarter 2022  Fourth quarter 2021 to fourth quarter 2022         Fourth quarter 2021 to fourth quarter 2022
# NaN                                dollars              dollars              dollars                                                                                      %
# All households                     1000667              936181               -64486                                                                                    -6.4
# Lowest and second wealth quintiles 72507                60679                -11828                                                                                   -16.3
# ...

# %%
# Define the column widths and the header row
Networth_quintile = 10
Fourth_quarter2021 = 10
Fourth_quarter2022 = 10
Fourth_quarter202to2022=10
header = f"{'Net worth by wealth quintile, average dollars per household'.ljust(Networth_quintile)}  /   {'Fourth quarter 2021'.ljust(Fourth_quarter2021)}   /   {'Fourth quarter 2022'.ljust(Fourth_quarter2022)} /  {'Fourth quarter 2021 to 2022'.ljust(Fourth_quarter202to2022)} "

row1 = f"{'Lowest and second wealth quintile'.ljust(Networth_quintile)}           ${str(72507).ljust(Fourth_quarter2021)}                ${str(60679).ljust(Fourth_quarter2022)}             ${str(-11828).ljust(Fourth_quarter202to2022)}"
row2 = f"{'Third wealth quintile'.ljust(Networth_quintile)}                       ${str(474761).ljust(Fourth_quarter2021)}                ${str(428340).ljust(Fourth_quarter2022)}             ${str(-46421).ljust(Fourth_quarter202to2022)}"
row3 = f"{'Fourth wealth quintile'.ljust(Networth_quintile)}                      ${str(1028766).ljust(Fourth_quarter2021)}               ${str(951003).ljust(Fourth_quarter2022)}              ${str(-77763).ljust(Fourth_quarter202to2022)}"
row4 = f"{'Highest wealth quintile'.ljust(Networth_quintile)}                     ${str(3354795).ljust(Fourth_quarter2021)}               ${str(3180203).ljust(Fourth_quarter2022)}              ${str(-174592).ljust(Fourth_quarter202to2022)}"

# Print the table
print(header)
print("-" * len(header))
print(row1)
print(row2)
print(row3)
print(row4)
# Out:
# Net worth by wealth quintile, average dollars per household  /   Fourth quarter 2021   /   Fourth quarter 2022 /  Fourth quarter 2021 to 2022
# ----------------------------------------------------------------------------------------------------------------------------------------------
# Lowest and second wealth quintile           $72507                     $60679                  $-11828
# Third wealth quintile                       $474761                    $428340                 $-46421
# Fourth wealth quintile                      $1028766                  $951003                  $-77763
# Highest wealth quintile                     $3354795                  $3180203                 $-174592

# %%
# Define the data
labels = ['Lowest and second wealth quintile', 'Third wealth quintile', 'Fourth wealth quintile', 'Highest wealth quintile']
values_2021 = [72507, 474761, 1028766, 3354795]
values_2022 = [60679, 428340, 951003, 3180203]
changes = [-11828, -46421, -77763, -174592]

# Create the horizontal bar chart
fig, ax = plt.subplots(figsize=(8, 5))
ax.barh(labels, values_2021, height=0.4, color='#5fba7d', label='Fourth quarter 2021')
ax.barh(labels, values_2022, height=0.4, color='#ffb347', label='Fourth quarter 2022')
ax.legend()
ax.set_xlabel('Average net worth per household (dollars)')
ax.set_ylabel('Wealth quintile')
ax.set_title('Net worth by wealth quintile, fourth quarter 2021 vs fourth quarter 2022')

# Add the changes as text labels
for i, change in enumerate(changes):
    ax.text(values_2022[i] + 20000, i, f'({change:+,d})', va='center')

plt.show()

# %%
# Define the data as a dictionary
data = {
    'Net worth by wealth quintile': ['Lowest and second wealth quintile', 'Third wealth quintile', 'Fourth wealth quintile', 'Highest wealth quintile'],
    'Fourth quarter 2021': [72507, 474761, 1028766, 3354795],
    'Fourth quarter 2022': [60679, 428340, 951003, 3180203],
    'Fourth quarter 2021 to 2022': [-11828, -46421, -77763, -174592]
}

# Create a dataframe from the data
df = pd.DataFrame(data)

# Set the index to be the 'Net worth by wealth quintile' column
df.set_index('Net worth by wealth quintile', inplace=True)

# Plot the graph
ax = df.plot(kind='bar', figsize=(10,6))
ax.set_xlabel('Net worth by wealth quintile')
ax.set_ylabel('Average dollars per household')
ax.set_title('Net worth by wealth quintile')

# Show the plot
plt.show()
